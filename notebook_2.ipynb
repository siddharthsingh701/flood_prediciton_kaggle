# %%
# %cd /teamspace/studios/this_studio/2024/07/flood_prediction_notebook/flood_prediciton_code
# Out:
# /teamspace/studios/this_studio/2024/07/flood_prediction_notebook/flood_prediciton_code

# %%
# Basic Libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import mlflow
import gc
from warnings import filterwarnings
filterwarnings('ignore')

# Models Libs
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.base import BaseEstimator, TransformerMixin
from catboost import CatBoostRegressor
import xgboost as xgb
from sklearn import svm as svm
import lightgbm as lgbm
from lightgbm import LGBMRegressor

# Preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV

# Metric
from sklearn.metrics import r2_score

# Mlflow
import mlflow

# %%
TEST_SIZE = 0.2
DROP_COLUMNS = ['id']
CV = 3
RANDOM_STATE = 42
ORIGINAL_COLS = ['id','MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
       'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
       'Siltation', 'AgriculturalPractices', 'Encroachments',
       'IneffectiveDisasterPreparedness', 'DrainageSystems',
       'CoastalVulnerability', 'Landslides', 'Watersheds',
       'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
       'InadequatePlanning', 'PoliticalFactors', 'FloodProbability']

# GridSearchCV Params
PARAMS_LINEAR_REGRESSION = {}

PARAMS_XGB = {}

PARAMS_RANDOM_FOREST_REGRESSION = {
    'n_estimators':[100,200], 
    # 'criterion':['squared_error','absolute_error','friedman_mse','poisson']
}

PARAMS_LASSO = {
    'alpha':[0.1,0.01], 
    'max_iter':[100,500]
}

PARAMS_RIDGE = {
    'alpha':[0.1,0.01], 
    'max_iter':[100,500]
}

PARAMS_SVM = {
    'C': [1, 10], 
    'kernel': ['linear', 'rbf']
}

PARAMS_DEFAULT = {}

# %%
raw_train = pd.read_csv('../data/train.csv')
raw_valid= pd.read_csv('../data/test.csv')

# %%
def process_data(train_data,func_num):
    fun_dict = {
        1: create_features_1,
        2: create_features_2,
        3: create_features_3,
    }
    feature_func = fun_dict.get(func_num)
    df = train_data.copy()
    df = feature_func(df)
    # Drop Columns
    df.drop(columns=DROP_COLUMNS,axis=1,inplace=True)
    return df

def evaluate_model(model_name):
    # Linear Regression Model
    if model_name=='linear_regression':
        model =  GridSearchCV(
            estimator=LinearRegression(),
            param_grid=PARAMS_LINEAR_REGRESSION,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model.fit(X_train,y_train)
        # Predict on Test
        y_pred = model.predict(X_test)
        # Score 
        score = r2_score(y_test, y_pred)
    
    # LASSO
    if model_name=='lasso':
        model =  GridSearchCV(
            estimator=Lasso(),
            param_grid=PARAMS_LASSO,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model.fit(X_train,y_train)
        # Predict on Test
        y_pred = model.predict(X_test)
        # Score 
        score = r2_score(y_test, y_pred)

    # SVM Model
    if model_name=='svm':
        model =  GridSearchCV(
            estimator=svm.SVR(),
            param_grid=PARAMS_SVM,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model.fit(X_train,y_train)
        # Predict on Test
        y_pred = model.predict(X_test)
        # Score 
        score = r2_score(y_test, y_pred)
        print(f'Finished training model {model_name}')

    # XGBoost
    if model_name=='xgb':
        model =  GridSearchCV(
            estimator=xgb.XGBRegressor(),
            param_grid=PARAMS_XGB,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model.fit(X_train,y_train)
        # Predict on Test
        y_pred = model.predict(X_test)
        # Score 
        score = r2_score(y_test, y_pred)
        print(f'Finished training model {model_name}')

    # LightGBM
    if model_name=='lgbm':
        model =  GridSearchCV(
            estimator=LGBMRegressor(),
            param_grid=PARAMS_DEFAULT,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model.fit(X_train,y_train)
        # Predict on Test
        y_pred = model.predict(X_test)
        # Score 
        score = r2_score(y_test, y_pred)
        print(f'Finished training model {model_name}')

    # CatBoost
    if model_name=='catboost':
        model =  GridSearchCV(
            estimator=CatBoostRegressor(),
            param_grid=PARAMS_DEFAULT,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model.fit(X_train,y_train)
        # Predict on Test
        y_pred = model.predict(X_test)
        # Score 
        score = r2_score(y_test, y_pred)
        print(f'Finished training model {model_name}')
    
    # Ensemble
    if model_name=='ensemble':
        model_cat =  GridSearchCV(
            estimator=CatBoostRegressor(),
            param_grid=PARAMS_DEFAULT,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model_cat.fit(X_train,y_train)
        # Predict on Test
        y_pred_cat = model_cat.predict(X_test)

        model_xgb =  GridSearchCV(
            estimator=xgb.XGBRegressor(),
            param_grid=PARAMS_XGB,
            cv=CV,
            n_jobs=-1,
            verbose=2,
            scoring='neg_mean_squared_error')
        # Train Model
        model_xgb.fit(X_train,y_train)
        # Predict on Test
        y_pred_xgb = model_xgb.predict(X_test)

        y_pred_final = (y_pred_xgb + y_pred_cat) / 2

        model = model_xgb
        # Score 
        score = r2_score(y_test, y_pred_final)
        print(f'Finished training model {model_name}')
    
    # 
    # Return
    return model_name,score,model.best_estimator_,model.best_params_

def run_experiment(model_name,exp_desc):
    mlflow.set_tracking_uri('http://127.0.0.1:5000')
    mlflow.set_experiment(model_name)
    with mlflow.start_run():
        print('Model Name : ',model_name)
        model_name,score,best_model,best_param = evaluate_model(model_name)
        mlflow.log_param('drop_columns', DROP_COLUMNS)
        mlflow.log_param('model_name',model_name)
        mlflow.log_param('desc',exp_desc)
        mlflow.log_params(best_param)
        mlflow.log_param('cv',CV)
        mlflow.log_param('random_state',RANDOM_STATE)
        mlflow.log_param('features', str(list(valid_X_scaled.columns)))
        mlflow.log_metric('r2',score)
        mlflow.sklearn.log_model(best_model,model_name)
        # mlflow.log_artifact('transformed_data.csv')
    return best_model

def get_submission_csv(model):
    predictions = model.predict(valid_X_scaled)
    sub_df = raw_valid[['id']]
    sub_df['FloodProbability'] = predictions
    sub_df.to_csv('../data/submission.csv',index=False)

# %%
def create_features_1(data):
    df = data.copy()
    cols = ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
       'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
       'Siltation', 'AgriculturalPractices', 'Encroachments',
       'IneffectiveDisasterPreparedness', 'DrainageSystems',
       'CoastalVulnerability', 'Landslides', 'Watersheds',
       'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
       'InadequatePlanning', 'PoliticalFactors']
    df['ClimateImpact'] = df.MonsoonIntensity+df.ClimateChange
    df['AnthropogenicPressure'] = df.Deforestation+df.Urbanization+df.AgriculturalPractices+df.Encroachments
    df['InfrastructureQuality'] = df.DamsQuality+df.DrainageSystems+df.DeterioratingInfrastructure
    df['CoastalVulnerabilityTotal'] = df.CoastalVulnerability+df.Landslides
    df['PreventiveMeasuresEfficiency'] = df.RiverManagement+df.IneffectiveDisasterPreparedness+df.InadequatePlanning
    df['EcosystemImpact'] = df.WetlandLoss+df.Watersheds
    df['SocioPoliticalContext'] = df.PopulationScore+df.PoliticalFactors
    df['Land_Use_Pressure'] = df.Urbanization+df.Deforestation+df.AgriculturalPractices
    df['Environmental_Degradation']=df.Deforestation+df.Siltation+df.WetlandLoss+df.Landslides
    df['Infrastructure_Vulnerability'] = df.DeterioratingInfrastructure+df.InadequatePlanning
    df['Community_Preparednessg']= df.IneffectiveDisasterPreparedness+df.PoliticalFactors
    df['Population_Density_Vulnerable_Areas']= df.PopulationScore+df.CoastalVulnerability
    df['Climate_Change_Impact']= df.ClimateChange+df.MonsoonIntensity
    df['River_Health']= df.RiverManagement+df.DamsQuality
    df['ClimateImpact'] = df.MonsoonIntensity+df.ClimateChange
    df['AnthropogenicPressure'] = df.Deforestation+df.Urbanization+df.AgriculturalPractices+df.Encroachments
    df['InfrastructureQuality'] = df.DamsQuality+df.DrainageSystems+df.DeterioratingInfrastructure
    df['CoastalVulnerabilityTotal'] = df.CoastalVulnerability+df.Landslides
    df['PreventiveMeasuresEfficiency'] = df.RiverManagement+df.IneffectiveDisasterPreparedness+df.InadequatePlanning
    df['EcosystemImpact'] = df.WetlandLoss+df.Watersheds
    df['SocioPoliticalContext'] = df.PopulationScore+df.PoliticalFactors
    df['Land_Use_Pressure']=df.Urbanization+df.Deforestation+df.AgriculturalPractices
    df['Environmental_Degradation']=df.Deforestation+df.Siltation+df.WetlandLoss+df.Landslides
    df['Infrastructure_Vulnerability'] = df.DeterioratingInfrastructure+df.InadequatePlanning
    df['Community_Preparednessg']= df.IneffectiveDisasterPreparedness+df.PoliticalFactors
    df['Population_Density_Vulnerable_Areas']= df.PopulationScore+df.CoastalVulnerability
    df['Climate_Change_Impact']= df.ClimateChange+df.MonsoonIntensity
    df['River_Health']= df.RiverManagement+df.DamsQuality
    df['sum']= df.sum(axis=1)
    df['mean']= df.mean(axis=1)
    df['std'] = df.std(axis=1)
    df['max'] = df.max(axis=1)
    df['min'] = df.min(axis=1)
    df['var'] = df.var(axis=1)
    df['skew'] = df.skew(axis=1)
    df['kurt'] = df.kurt(axis=1)
    df['meadian'] = df.median(axis=1)
    df['quant_25'] = df.quantile(0.25,axis=1)
    df['quant_75'] = df.quantile(0.75,axis=1)
    df['sum>72'] = np.where(df['sum']>72,1,0)
    df['sum>100'] = np.where(df['sum']>100,1,0)
    df['sum>50'] = np.where(df['sum']>50,1,0)
    df['range']= df['max']-df['min']
    for col in cols:
        df[f"{col}_2"]= df[col]**2
        df[f"{col}_3"]= df[col]**3
        df[f"{col}_3"]= df[col]**4
    for col in cols:
        if col not in ['id','FloodProbability']:
            df[f"mad_{col}"] = df[col] - df[col].median()
            df[f"mean_{col}"] = df[col] - df[col].mean()
            df[f"std_{col}"] = df[col] - df[col].std()
    return df

def create_features_2(data):
    df = data.copy()
    cols = ['MonsoonIntensity', 'TopographyDrainage', 'RiverManagement',
       'Deforestation', 'Urbanization', 'ClimateChange', 'DamsQuality',
       'Siltation', 'AgriculturalPractices', 'Encroachments',
       'IneffectiveDisasterPreparedness', 'DrainageSystems',
       'CoastalVulnerability', 'Landslides', 'Watersheds',
       'DeterioratingInfrastructure', 'PopulationScore', 'WetlandLoss',
       'InadequatePlanning', 'PoliticalFactors']
    df['ClimateImpact'] = df.MonsoonIntensity+df.ClimateChange
    df['AnthropogenicPressure'] = df.Deforestation+df.Urbanization+df.AgriculturalPractices+df.Encroachments
    df['InfrastructureQuality'] = df.DamsQuality+df.DrainageSystems+df.DeterioratingInfrastructure
    df['CoastalVulnerabilityTotal'] = df.CoastalVulnerability+df.Landslides
    df['PreventiveMeasuresEfficiency'] = df.RiverManagement+df.IneffectiveDisasterPreparedness+df.InadequatePlanning
    df['EcosystemImpact'] = df.WetlandLoss+df.Watersheds
    df['SocioPoliticalContext'] = df.PopulationScore+df.PoliticalFactors
    df['Land_Use_Pressure'] = df.Urbanization+df.Deforestation+df.AgriculturalPractices
    df['Environmental_Degradation']=df.Deforestation+df.Siltation+df.WetlandLoss+df.Landslides
    df['Infrastructure_Vulnerability'] = df.DeterioratingInfrastructure+df.InadequatePlanning
    df['Community_Preparednessg']= df.IneffectiveDisasterPreparedness+df.PoliticalFactors
    df['Population_Density_Vulnerable_Areas']= df.PopulationScore+df.CoastalVulnerability
    df['Climate_Change_Impact']= df.ClimateChange+df.MonsoonIntensity
    df['River_Health']= df.RiverManagement+df.DamsQuality
    df['ClimateImpact'] = df.MonsoonIntensity+df.ClimateChange
    df['AnthropogenicPressure'] = df.Deforestation+df.Urbanization+df.AgriculturalPractices+df.Encroachments
    df['InfrastructureQuality'] = df.DamsQuality+df.DrainageSystems+df.DeterioratingInfrastructure
    df['CoastalVulnerabilityTotal'] = df.CoastalVulnerability+df.Landslides
    df['PreventiveMeasuresEfficiency'] = df.RiverManagement+df.IneffectiveDisasterPreparedness+df.InadequatePlanning
    df['EcosystemImpact'] = df.WetlandLoss+df.Watersheds
    df['SocioPoliticalContext'] = df.PopulationScore+df.PoliticalFactors
    df['Land_Use_Pressure']=df.Urbanization+df.Deforestation+df.AgriculturalPractices
    df['Environmental_Degradation']=df.Deforestation+df.Siltation+df.WetlandLoss+df.Landslides
    df['Infrastructure_Vulnerability'] = df.DeterioratingInfrastructure+df.InadequatePlanning
    df['Community_Preparednessg']= df.IneffectiveDisasterPreparedness+df.PoliticalFactors
    df['Population_Density_Vulnerable_Areas']= df.PopulationScore+df.CoastalVulnerability
    df['Climate_Change_Impact']= df.ClimateChange+df.MonsoonIntensity
    df['River_Health']= df.RiverManagement+df.DamsQuality
    df['sum']= df.sum(axis=1)
    df['mean']= df.mean(axis=1)
    df['std'] = df.std(axis=1)
    df['max'] = df.max(axis=1)
    df['min'] = df.min(axis=1)
    df['var'] = df.var(axis=1)
    df['skew'] = df.skew(axis=1)
    df['kurt'] = df.kurt(axis=1)
    df['meadian'] = df.median(axis=1)
    df['quant_25'] = df.quantile(0.25,axis=1)
    df['quant_75'] = df.quantile(0.75,axis=1)
    df['sum>72'] = np.where(df['sum']>72,1,0)
    df['sum>100'] = np.where(df['sum']>100,1,0)
    df['sum>50'] = np.where(df['sum']>50,1,0)
    df['range']= df['max']-df['min']
    for col in cols:
        df[f"{col}_2"]= df[col]**2
        df[f"{col}_3"]= df[col]**3
        df[f"{col}_3"]= df[col]**4
        # Log Features
        df[f"log_{col}"] = np.log1p(df[col]+1e-4)  
    for col in cols:
        if col not in ['id','FloodProbability']:
            df[f"mad_{col}"] = df[col] - df[col].median()
            df[f"mean_{col}"] = df[col] - df[col].mean()
            df[f"std_{col}"] = df[col] - df[col].std()
    return df

def create_features_3(data):
    pass

# %%
# Train Test Split and Scaling
raw_train_X = raw_train.drop('FloodProbability',axis=1)
raw_train_y = raw_train['FloodProbability']

train_X = process_data(raw_train_X,1)
train_y = raw_train_y

sc = MinMaxScaler()
sc.fit(train_X)
train_X_scaled = sc.transform(train_X)
train_X_scaled = pd.DataFrame(train_X,columns=train_X.columns)

X_train, X_test, y_train, y_test = train_test_split(train_X_scaled, train_y, test_size=TEST_SIZE, random_state=RANDOM_STATE)

valid_X = process_data(raw_valid,1)
valid_X_scaled = sc.transform(valid_X)
valid_X_scaled = pd.DataFrame(valid_X_scaled,columns=valid_X.columns)

# %%
train_X_scaled.shape, valid_X_scaled.shape
# Out:
# ((1117957, 149), (745305, 149))

# %%
del raw_train_X,raw_train_y,train_X,train_y,train_X_scaled
gc.collect()
# Out:
# 0

# %%
Experiment_Desc = 'All Features + Log Features'
md_lr = run_experiment('linear_regression',Experiment_Desc)
md_lgbm =run_experiment('lgbm',Experiment_Desc)
md_xgb = run_experiment('xgb',Experiment_Desc)
md_catboost =run_experiment('catboost',Experiment_Desc)
# Out:
# 2024/07/12 17:28:15 INFO mlflow.tracking.fluent: Experiment with name 'linear_regression' does not exist. Creating a new experiment.
# Model Name :  linear_regression
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................................................... total time=  36.9s
# [CV] END .................................................... total time=  38.2s
# [CV] END .................................................... total time=  38.8s
# 2024/07/12 17:29:40 INFO mlflow.tracking.fluent: Experiment with name 'lgbm' does not exist. Creating a new experiment.
# Model Name :  lgbm
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.545334 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 5097
# [LightGBM] [Info] Number of data points in the train set: 596243, number of used features: 146
# [LightGBM] [Info] Start training from score 0.504457
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 2.274513 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5097
# [LightGBM] [Info] Number of data points in the train set: 596244, number of used features: 146
# [LightGBM] [Info] Start training from score 0.504488
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.904687 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5082
# [LightGBM] [Info] Number of data points in the train set: 596243, number of used features: 146
# [LightGBM] [Info] Start training from score 0.504496
# [CV] END .................................................... total time= 2.2min
# [CV] END .................................................... total time= 2.3min
# [CV] END .................................................... total time= 2.3min
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 1.254708 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5096
# [LightGBM] [Info] Number of data points in the train set: 894365, number of used features: 146
# [LightGBM] [Info] Start training from score 0.504480
# Finished training model lgbm
# 2024/07/12 17:33:01 INFO mlflow.tracking.fluent: Experiment with name 'xgb' does not exist. Creating a new experiment.
# Model Name :  xgb
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV] END .................................................... total time=  46.0s
# [CV] END .................................................... total time=  47.5s
# [CV] END .................................................... total time=  49.7s
# Finished training model xgb
# 2024/07/12 17:34:32 INFO mlflow.tracking.fluent: Experiment with name 'catboost' does not exist. Creating a new experiment.
# Model Name :  catboost
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# Learning rate set to 0.112382
# Learning rate set to 0.112382
# 0:	learn: 0.0476190	total: 595ms	remaining: 9m 54s
# 0:	learn: 0.0476323	total: 712ms	remaining: 11m 51s
# 1:	learn: 0.0447045	total: 1.18s	remaining: 9m 50s
# 1:	learn: 0.0447105	total: 1.3s	remaining: 10m 47s
# 2:	learn: 0.0422128	total: 1.89s	remaining: 10m 28s
# 2:	learn: 0.0422148	total: 1.94s	remaining: 10m 44s
# 3:	learn: 0.0400816	total: 2.56s	remaining: 10m 36s
# 3:	learn: 0.0401146	total: 2.66s	remaining: 11m 2s
# 4:	learn: 0.0382983	total: 3.19s	remaining: 10m 35s
# 4:	learn: 0.0383497	total: 3.33s	remaining: 11m 2s
# 5:	learn: 0.0367705	total: 3.74s	remaining: 10m 19s
# 5:	learn: 0.0367230	total: 4.19s	remaining: 11m 33s
# Learning rate set to 0.112382
# 6:	learn: 0.0353820	total: 4.47s	remaining: 10m 33s
# 6:	learn: 0.0353392	total: 4.77s	remaining: 11m 17s
# 7:	learn: 0.0342422	total: 5.13s	remaining: 10m 36s
# 7:	learn: 0.0341700	total: 5.24s	remaining: 10m 50s
# 0:	learn: 0.0475958	total: 728ms	remaining: 12m 7s
# 8:	learn: 0.0331965	total: 5.7s	remaining: 10m 27s
# 1:	learn: 0.0446896	total: 1.22s	remaining: 10m 10s
# 8:	learn: 0.0331488	total: 5.89s	remaining: 10m 49s
# 9:	learn: 0.0323214	total: 6.13s	remaining: 10m 6s
# 2:	learn: 0.0421781	total: 1.89s	remaining: 10m 28s
# 9:	learn: 0.0322958	total: 6.6s	remaining: 10m 53s
# 10:	learn: 0.0315701	total: 6.67s	remaining: 9m 59s
# 3:	learn: 0.0400710	total: 2.59s	remaining: 10m 44s
# 11:	learn: 0.0309111	total: 7.31s	remaining: 10m 1s
# 10:	learn: 0.0315476	total: 7.26s	remaining: 10m 52s
# 12:	learn: 0.0303333	total: 7.77s	remaining: 9m 49s
# 11:	learn: 0.0308807	total: 7.85s	remaining: 10m 46s
# 4:	learn: 0.0382945	total: 3.32s	remaining: 11m
# 13:	learn: 0.0298217	total: 8.22s	remaining: 9m 38s
# 12:	learn: 0.0302944	total: 8.35s	remaining: 10m 33s
# 5:	learn: 0.0367705	total: 3.89s	remaining: 10m 44s
# 14:	learn: 0.0293611	total: 8.79s	remaining: 9m 37s
# 13:	learn: 0.0297762	total: 8.91s	remaining: 10m 27s
# 6:	learn: 0.0353776	total: 4.44s	remaining: 10m 29s
# 15:	learn: 0.0289039	total: 9.49s	remaining: 9m 43s
# 14:	learn: 0.0293049	total: 9.51s	remaining: 10m 24s
# 7:	learn: 0.0341595	total: 4.97s	remaining: 10m 16s
# 15:	learn: 0.0288757	total: 10.1s	remaining: 10m 21s
# 16:	learn: 0.0285030	total: 10.2s	remaining: 9m 50s
# 8:	learn: 0.0331551	total: 5.66s	remaining: 10m 23s
# 17:	learn: 0.0281616	total: 10.7s	remaining: 9m 41s
# 16:	learn: 0.0284694	total: 10.9s	remaining: 10m 32s
# 18:	learn: 0.0278530	total: 11s	remaining: 9m 28s
# 9:	learn: 0.0322850	total: 6.36s	remaining: 10m 29s
# 17:	learn: 0.0281388	total: 11.6s	remaining: 10m 30s
# 19:	learn: 0.0275676	total: 11.6s	remaining: 9m 30s
# 10:	learn: 0.0315253	total: 7.06s	remaining: 10m 34s
# 20:	learn: 0.0273088	total: 12.2s	remaining: 9m 30s
# 18:	learn: 0.0278072	total: 12.2s	remaining: 10m 29s
# 11:	learn: 0.0308512	total: 7.65s	remaining: 10m 30s
# 19:	learn: 0.0275271	total: 12.7s	remaining: 10m 20s
# 21:	learn: 0.0270486	total: 12.8s	remaining: 9m 30s
# 12:	learn: 0.0302709	total: 8.3s	remaining: 10m 30s
# 20:	learn: 0.0272774	total: 13.1s	remaining: 10m 12s
# 22:	learn: 0.0268321	total: 13.5s	remaining: 9m 35s
# 13:	learn: 0.0297552	total: 8.9s	remaining: 10m 26s
# 21:	learn: 0.0270202	total: 13.6s	remaining: 10m 2s
# 14:	learn: 0.0292883	total: 9.46s	remaining: 10m 21s
# 23:	learn: 0.0265916	total: 14.2s	remaining: 9m 38s
# 22:	learn: 0.0267718	total: 14.3s	remaining: 10m 7s
# 15:	learn: 0.0288754	total: 9.99s	remaining: 10m 14s
# 24:	learn: 0.0263937	total: 14.7s	remaining: 9m 34s
# 23:	learn: 0.0265566	total: 14.9s	remaining: 10m 6s
# 16:	learn: 0.0285126	total: 10.6s	remaining: 10m 11s
# 25:	learn: 0.0262073	total: 15.3s	remaining: 9m 34s
# 24:	learn: 0.0263711	total: 15.3s	remaining: 9m 58s
# 17:	learn: 0.0281826	total: 11.1s	remaining: 10m 3s
# 26:	learn: 0.0260238	total: 15.9s	remaining: 9m 33s
# 25:	learn: 0.0261856	total: 16s	remaining: 9m 59s
# 18:	learn: 0.0278835	total: 11.6s	remaining: 9m 59s
# 27:	learn: 0.0258611	total: 16.5s	remaining: 9m 31s
# 26:	learn: 0.0260075	total: 16.6s	remaining: 9m 58s
# 19:	learn: 0.0276093	total: 12.1s	remaining: 9m 54s
# 28:	learn: 0.0257059	total: 17s	remaining: 9m 28s
# 27:	learn: 0.0258408	total: 17.4s	remaining: 10m 3s
# 20:	learn: 0.0273223	total: 12.8s	remaining: 9m 58s
# 29:	learn: 0.0255761	total: 17.5s	remaining: 9m 27s
# 28:	learn: 0.0256913	total: 18s	remaining: 10m 1s
# 21:	learn: 0.0270538	total: 13.5s	remaining: 9m 58s
# 30:	learn: 0.0254386	total: 18.2s	remaining: 9m 28s
# 29:	learn: 0.0255548	total: 18.4s	remaining: 9m 55s
# 22:	learn: 0.0268241	total: 14.1s	remaining: 9m 57s
# 31:	learn: 0.0253091	total: 18.9s	remaining: 9m 31s
# 30:	learn: 0.0254175	total: 19.1s	remaining: 9m 55s
# 23:	learn: 0.0265928	total: 14.7s	remaining: 9m 57s
# 32:	learn: 0.0251956	total: 19.4s	remaining: 9m 29s
# 31:	learn: 0.0252913	total: 19.6s	remaining: 9m 52s
# 24:	learn: 0.0263962	total: 15.2s	remaining: 9m 52s
# 33:	learn: 0.0250889	total: 20s	remaining: 9m 28s
# 32:	learn: 0.0251754	total: 20.2s	remaining: 9m 53s
# 25:	learn: 0.0262145	total: 15.8s	remaining: 9m 51s
# 34:	learn: 0.0249817	total: 20.5s	remaining: 9m 25s
# 33:	learn: 0.0250650	total: 20.8s	remaining: 9m 49s
# 26:	learn: 0.0260300	total: 16.3s	remaining: 9m 48s
# 35:	learn: 0.0248872	total: 21.1s	remaining: 9m 24s
# 34:	learn: 0.0249618	total: 21.4s	remaining: 9m 49s
# 36:	learn: 0.0247975	total: 21.5s	remaining: 9m 20s
# 27:	learn: 0.0258635	total: 17.1s	remaining: 9m 53s
# 35:	learn: 0.0248678	total: 21.8s	remaining: 9m 44s
# 37:	learn: 0.0247134	total: 22.2s	remaining: 9m 22s
# 28:	learn: 0.0257106	total: 17.7s	remaining: 9m 53s
# 36:	learn: 0.0247810	total: 22.4s	remaining: 9m 42s
# 38:	learn: 0.0246311	total: 22.8s	remaining: 9m 21s
# 29:	learn: 0.0255689	total: 18.2s	remaining: 9m 49s
# 37:	learn: 0.0246956	total: 23.1s	remaining: 9m 43s
# 30:	learn: 0.0254390	total: 18.6s	remaining: 9m 42s
# 39:	learn: 0.0245546	total: 23.4s	remaining: 9m 22s
# 38:	learn: 0.0246110	total: 23.7s	remaining: 9m 44s
# 31:	learn: 0.0253115	total: 19.2s	remaining: 9m 41s
# 40:	learn: 0.0244852	total: 24.1s	remaining: 9m 24s
# 39:	learn: 0.0245338	total: 24.3s	remaining: 9m 43s
# 32:	learn: 0.0251918	total: 19.8s	remaining: 9m 41s
# 41:	learn: 0.0244202	total: 24.6s	remaining: 9m 20s
# 40:	learn: 0.0244634	total: 24.8s	remaining: 9m 39s
# 33:	learn: 0.0250833	total: 20.3s	remaining: 9m 35s
# 42:	learn: 0.0243568	total: 25.2s	remaining: 9m 20s
# 41:	learn: 0.0243971	total: 25.2s	remaining: 9m 35s
# 34:	learn: 0.0249805	total: 20.8s	remaining: 9m 33s
# 43:	learn: 0.0242969	total: 25.6s	remaining: 9m 17s
# 42:	learn: 0.0243375	total: 25.7s	remaining: 9m 32s
# 35:	learn: 0.0248856	total: 21.3s	remaining: 9m 29s
# 44:	learn: 0.0242436	total: 26.3s	remaining: 9m 18s
# 43:	learn: 0.0242833	total: 26.3s	remaining: 9m 32s
# 36:	learn: 0.0247935	total: 22.2s	remaining: 9m 36s
# 45:	learn: 0.0241900	total: 27s	remaining: 9m 20s
# 44:	learn: 0.0242251	total: 27.1s	remaining: 9m 36s
# 37:	learn: 0.0247110	total: 22.8s	remaining: 9m 37s
# 46:	learn: 0.0241302	total: 27.6s	remaining: 9m 19s
# 45:	learn: 0.0241734	total: 27.7s	remaining: 9m 34s
# 38:	learn: 0.0246328	total: 23.3s	remaining: 9m 34s
# 47:	learn: 0.0240819	total: 28.1s	remaining: 9m 16s
# 46:	learn: 0.0241233	total: 28.2s	remaining: 9m 32s
# 39:	learn: 0.0245541	total: 23.8s	remaining: 9m 31s
# 48:	learn: 0.0240334	total: 28.6s	remaining: 9m 15s
# 47:	learn: 0.0240747	total: 28.8s	remaining: 9m 30s
# 40:	learn: 0.0244827	total: 24.3s	remaining: 9m 29s
# 49:	learn: 0.0239841	total: 29.1s	remaining: 9m 12s
# 48:	learn: 0.0240254	total: 29.4s	remaining: 9m 30s
# 41:	learn: 0.0244176	total: 24.9s	remaining: 9m 27s
# 50:	learn: 0.0239406	total: 29.6s	remaining: 9m 10s
# 42:	learn: 0.0243554	total: 25.4s	remaining: 9m 24s
# 49:	learn: 0.0239674	total: 30s	remaining: 9m 30s
# 51:	learn: 0.0238921	total: 30.2s	remaining: 9m 9s
# 52:	learn: 0.0238510	total: 30.6s	remaining: 9m 7s
# 50:	learn: 0.0239244	total: 30.6s	remaining: 9m 29s
# 43:	learn: 0.0242915	total: 26.2s	remaining: 9m 30s
# 51:	learn: 0.0238804	total: 31.1s	remaining: 9m 27s
# 53:	learn: 0.0238057	total: 31.4s	remaining: 9m 9s
# 44:	learn: 0.0242324	total: 26.9s	remaining: 9m 30s
# 54:	learn: 0.0237647	total: 31.8s	remaining: 9m 7s
# 52:	learn: 0.0238380	total: 31.8s	remaining: 9m 28s
# 45:	learn: 0.0241789	total: 27.3s	remaining: 9m 26s
# 55:	learn: 0.0237231	total: 32.3s	remaining: 9m 5s
# 46:	learn: 0.0241219	total: 27.8s	remaining: 9m 23s
# 53:	learn: 0.0237933	total: 32.4s	remaining: 9m 27s
# 47:	learn: 0.0240715	total: 28.2s	remaining: 9m 19s
# 56:	learn: 0.0236774	total: 32.9s	remaining: 9m 4s
# 54:	learn: 0.0237487	total: 33s	remaining: 9m 26s
# 48:	learn: 0.0240220	total: 28.7s	remaining: 9m 17s
# 55:	learn: 0.0237118	total: 33.4s	remaining: 9m 23s
# 57:	learn: 0.0236357	total: 33.6s	remaining: 9m 5s
# 49:	learn: 0.0239757	total: 29.3s	remaining: 9m 16s
# 56:	learn: 0.0236643	total: 34.3s	remaining: 9m 28s
# 58:	learn: 0.0235930	total: 34.5s	remaining: 9m 9s
# 50:	learn: 0.0239306	total: 29.9s	remaining: 9m 16s
# 59:	learn: 0.0235559	total: 34.9s	remaining: 9m 7s
# 57:	learn: 0.0236261	total: 34.9s	remaining: 9m 26s
# 51:	learn: 0.0238880	total: 30.4s	remaining: 9m 13s
# 58:	learn: 0.0235886	total: 35.3s	remaining: 9m 23s
# 60:	learn: 0.0235204	total: 35.5s	remaining: 9m 6s
# 52:	learn: 0.0238458	total: 30.9s	remaining: 9m 12s
# 61:	learn: 0.0234881	total: 36s	remaining: 9m 4s
# 59:	learn: 0.0235464	total: 36s	remaining: 9m 23s
# 53:	learn: 0.0238063	total: 31.5s	remaining: 9m 11s
# 60:	learn: 0.0235122	total: 36.5s	remaining: 9m 21s
# 62:	learn: 0.0234459	total: 36.7s	remaining: 9m 5s
# 54:	learn: 0.0237684	total: 32s	remaining: 9m 10s
# 63:	learn: 0.0234138	total: 37.1s	remaining: 9m 2s
# 61:	learn: 0.0234736	total: 37.4s	remaining: 9m 25s
# 55:	learn: 0.0237266	total: 32.8s	remaining: 9m 13s
# 64:	learn: 0.0233781	total: 37.7s	remaining: 9m 2s
# 62:	learn: 0.0234436	total: 37.8s	remaining: 9m 22s
# 56:	learn: 0.0236849	total: 33.3s	remaining: 9m 11s
# 65:	learn: 0.0233482	total: 38.2s	remaining: 9m
# 57:	learn: 0.0236438	total: 33.8s	remaining: 9m 9s
# 63:	learn: 0.0234011	total: 38.4s	remaining: 9m 22s
# 66:	learn: 0.0233108	total: 38.8s	remaining: 8m 59s
# 58:	learn: 0.0235992	total: 34.4s	remaining: 9m 8s
# 64:	learn: 0.0233703	total: 39.1s	remaining: 9m 22s
# 67:	learn: 0.0232808	total: 39.2s	remaining: 8m 57s
# 59:	learn: 0.0235618	total: 34.9s	remaining: 9m 6s
# 68:	learn: 0.0232553	total: 39.8s	remaining: 8m 56s
# 65:	learn: 0.0233308	total: 39.7s	remaining: 9m 22s
# 60:	learn: 0.0235297	total: 35.5s	remaining: 9m 5s
# 66:	learn: 0.0233028	total: 40.1s	remaining: 9m 18s
# 69:	learn: 0.0232256	total: 40.3s	remaining: 8m 55s
# 67:	learn: 0.0232774	total: 40.6s	remaining: 9m 16s
# 70:	learn: 0.0231939	total: 40.8s	remaining: 8m 54s
# 61:	learn: 0.0234863	total: 36.2s	remaining: 9m 7s
# 68:	learn: 0.0232481	total: 41.1s	remaining: 9m 15s
# 71:	learn: 0.0231571	total: 41.4s	remaining: 8m 53s
# 62:	learn: 0.0234516	total: 36.7s	remaining: 9m 6s
# 72:	learn: 0.0231272	total: 41.8s	remaining: 8m 51s
# 69:	learn: 0.0232170	total: 41.7s	remaining: 9m 14s
# 63:	learn: 0.0234157	total: 37.3s	remaining: 9m 6s
# 73:	learn: 0.0231001	total: 42.5s	remaining: 8m 51s
# 70:	learn: 0.0231884	total: 42.5s	remaining: 9m 16s
# 64:	learn: 0.0233762	total: 38.1s	remaining: 9m 8s
# 74:	learn: 0.0230684	total: 43s	remaining: 8m 50s
# 71:	learn: 0.0231507	total: 43.1s	remaining: 9m 15s
# 65:	learn: 0.0233413	total: 38.7s	remaining: 9m 7s
# 75:	learn: 0.0230408	total: 43.5s	remaining: 8m 49s
# 72:	learn: 0.0231159	total: 43.8s	remaining: 9m 16s
# 66:	learn: 0.0233039	total: 39.3s	remaining: 9m 7s
# 76:	learn: 0.0230163	total: 44.2s	remaining: 8m 49s
# 73:	learn: 0.0230935	total: 44.3s	remaining: 9m 14s
# 67:	learn: 0.0232681	total: 39.9s	remaining: 9m 6s
# 77:	learn: 0.0229885	total: 44.9s	remaining: 8m 50s
# 68:	learn: 0.0232394	total: 40.3s	remaining: 9m 4s
# 74:	learn: 0.0230629	total: 45s	remaining: 9m 14s
# 78:	learn: 0.0229638	total: 45.4s	remaining: 8m 49s
# 75:	learn: 0.0230389	total: 45.4s	remaining: 9m 12s
# 69:	learn: 0.0232115	total: 40.9s	remaining: 9m 2s
# 79:	learn: 0.0229413	total: 45.9s	remaining: 8m 48s
# 76:	learn: 0.0230130	total: 45.9s	remaining: 9m 10s
# 70:	learn: 0.0231830	total: 41.3s	remaining: 9m
# 77:	learn: 0.0229880	total: 46.3s	remaining: 9m 7s
# 71:	learn: 0.0231545	total: 41.8s	remaining: 8m 59s
# 80:	learn: 0.0229159	total: 46.6s	remaining: 8m 48s
# 72:	learn: 0.0231304	total: 42.2s	remaining: 8m 56s
# 81:	learn: 0.0228958	total: 47s	remaining: 8m 46s
# 78:	learn: 0.0229600	total: 47s	remaining: 9m 7s
# 82:	learn: 0.0228768	total: 47.4s	remaining: 8m 43s
# 79:	learn: 0.0229350	total: 47.5s	remaining: 9m 6s
# 73:	learn: 0.0230984	total: 42.9s	remaining: 8m 57s
# 83:	learn: 0.0228524	total: 47.9s	remaining: 8m 42s
# 74:	learn: 0.0230711	total: 43.4s	remaining: 8m 55s
# 80:	learn: 0.0229048	total: 48.1s	remaining: 9m 5s
# 84:	learn: 0.0228301	total: 48.4s	remaining: 8m 40s
# 75:	learn: 0.0230476	total: 44s	remaining: 8m 54s
# 81:	learn: 0.0228767	total: 48.7s	remaining: 9m 4s
# 85:	learn: 0.0228027	total: 48.9s	remaining: 8m 40s
# 76:	learn: 0.0230115	total: 44.5s	remaining: 8m 53s
# 82:	learn: 0.0228553	total: 49.2s	remaining: 9m 3s
# 86:	learn: 0.0227776	total: 49.5s	remaining: 8m 38s
# 77:	learn: 0.0229861	total: 45s	remaining: 8m 51s
# 83:	learn: 0.0228324	total: 49.8s	remaining: 9m 3s
# 87:	learn: 0.0227580	total: 50s	remaining: 8m 37s
# 78:	learn: 0.0229594	total: 45.7s	remaining: 8m 52s
# 88:	learn: 0.0227385	total: 50.6s	remaining: 8m 37s
# 84:	learn: 0.0228050	total: 50.7s	remaining: 9m 6s
# 79:	learn: 0.0229354	total: 46.4s	remaining: 8m 53s
# 89:	learn: 0.0227192	total: 51.1s	remaining: 8m 37s
# 85:	learn: 0.0227862	total: 51.3s	remaining: 9m 4s
# 80:	learn: 0.0229056	total: 47s	remaining: 8m 52s
# 90:	learn: 0.0226979	total: 51.7s	remaining: 8m 36s
# 86:	learn: 0.0227633	total: 51.8s	remaining: 9m 3s
# 91:	learn: 0.0226806	total: 52s	remaining: 8m 33s
# 81:	learn: 0.0228834	total: 47.5s	remaining: 8m 52s
# 87:	learn: 0.0227409	total: 52.3s	remaining: 9m 2s
# 92:	learn: 0.0226605	total: 52.6s	remaining: 8m 33s
# 82:	learn: 0.0228623	total: 48s	remaining: 8m 50s
# 88:	learn: 0.0227188	total: 52.7s	remaining: 8m 59s
# 93:	learn: 0.0226413	total: 53.1s	remaining: 8m 31s
# 83:	learn: 0.0228371	total: 48.6s	remaining: 8m 49s
# 89:	learn: 0.0226971	total: 53.2s	remaining: 8m 57s
# 94:	learn: 0.0226143	total: 53.7s	remaining: 8m 31s
# 84:	learn: 0.0228163	total: 49.2s	remaining: 8m 49s
# 90:	learn: 0.0226740	total: 53.9s	remaining: 8m 58s
# 95:	learn: 0.0225986	total: 54.1s	remaining: 8m 29s
# 85:	learn: 0.0227939	total: 49.8s	remaining: 8m 48s
# 91:	learn: 0.0226466	total: 54.5s	remaining: 8m 57s
# 96:	learn: 0.0225720	total: 54.8s	remaining: 8m 30s
# 86:	learn: 0.0227706	total: 50.3s	remaining: 8m 47s
# 92:	learn: 0.0226292	total: 54.9s	remaining: 8m 55s
# 93:	learn: 0.0226089	total: 55.2s	remaining: 8m 51s
# 97:	learn: 0.0225496	total: 55.4s	remaining: 8m 29s
# 87:	learn: 0.0227495	total: 50.8s	remaining: 8m 45s
# 94:	learn: 0.0225881	total: 55.7s	remaining: 8m 50s
# 98:	learn: 0.0225309	total: 55.8s	remaining: 8m 27s
# 88:	learn: 0.0227270	total: 51.2s	remaining: 8m 44s
# 95:	learn: 0.0225705	total: 56s	remaining: 8m 47s
# 99:	learn: 0.0225122	total: 56.1s	remaining: 8m 25s
# 89:	learn: 0.0227081	total: 51.6s	remaining: 8m 41s
# 100:	learn: 0.0224938	total: 56.5s	remaining: 8m 23s
# 96:	learn: 0.0225451	total: 56.5s	remaining: 8m 46s
# 90:	learn: 0.0226830	total: 52.1s	remaining: 8m 40s
# 101:	learn: 0.0224728	total: 57s	remaining: 8m 21s
# 97:	learn: 0.0225249	total: 56.9s	remaining: 8m 44s
# 91:	learn: 0.0226648	total: 52.5s	remaining: 8m 37s
# 102:	learn: 0.0224555	total: 57.3s	remaining: 8m 18s
# 98:	learn: 0.0225047	total: 57.4s	remaining: 8m 41s
# 92:	learn: 0.0226458	total: 53s	remaining: 8m 36s
# 103:	learn: 0.0224382	total: 57.7s	remaining: 8m 17s
# 99:	learn: 0.0224834	total: 58s	remaining: 8m 42s
# 104:	learn: 0.0224184	total: 58.3s	remaining: 8m 17s
# 93:	learn: 0.0226232	total: 53.7s	remaining: 8m 38s
# 100:	learn: 0.0224669	total: 58.5s	remaining: 8m 40s
# 105:	learn: 0.0224019	total: 58.7s	remaining: 8m 15s
# 94:	learn: 0.0225992	total: 54.2s	remaining: 8m 36s
# 101:	learn: 0.0224468	total: 59s	remaining: 8m 39s
# 106:	learn: 0.0223894	total: 59.1s	remaining: 8m 13s
# 102:	learn: 0.0224286	total: 59.3s	remaining: 8m 36s
# 95:	learn: 0.0225805	total: 54.7s	remaining: 8m 34s
# 107:	learn: 0.0223730	total: 59.5s	remaining: 8m 11s
# 103:	learn: 0.0224134	total: 59.7s	remaining: 8m 34s
# 96:	learn: 0.0225524	total: 55.2s	remaining: 8m 33s
# 108:	learn: 0.0223547	total: 1m	remaining: 8m 10s
# 97:	learn: 0.0225356	total: 55.5s	remaining: 8m 30s
# 109:	learn: 0.0223339	total: 1m	remaining: 8m 8s
# 104:	learn: 0.0223861	total: 1m	remaining: 8m 34s
# 98:	learn: 0.0225151	total: 55.8s	remaining: 8m 28s
# 110:	learn: 0.0223197	total: 1m	remaining: 8m 6s
# 99:	learn: 0.0224956	total: 56.2s	remaining: 8m 25s
# 105:	learn: 0.0223659	total: 1m	remaining: 8m 33s
# 111:	learn: 0.0222983	total: 1m 1s	remaining: 8m 5s
# 100:	learn: 0.0224752	total: 56.6s	remaining: 8m 23s
# 106:	learn: 0.0223494	total: 1m 1s	remaining: 8m 30s
# 112:	learn: 0.0222845	total: 1m 1s	remaining: 8m 2s
# 101:	learn: 0.0224582	total: 56.9s	remaining: 8m 20s
# 107:	learn: 0.0223328	total: 1m 1s	remaining: 8m 28s
# 113:	learn: 0.0222674	total: 1m 1s	remaining: 8m 1s
# 108:	learn: 0.0223171	total: 1m 1s	remaining: 8m 26s
# 102:	learn: 0.0224335	total: 57.3s	remaining: 8m 19s
# 114:	learn: 0.0222495	total: 1m 2s	remaining: 7m 59s
# 103:	learn: 0.0224163	total: 57.6s	remaining: 8m 16s
# 109:	learn: 0.0223020	total: 1m 2s	remaining: 8m 24s
# 115:	learn: 0.0222322	total: 1m 2s	remaining: 7m 57s
# 104:	learn: 0.0223997	total: 58.1s	remaining: 8m 14s
# 110:	learn: 0.0222841	total: 1m 2s	remaining: 8m 23s
# 116:	learn: 0.0222096	total: 1m 3s	remaining: 7m 56s
# 105:	learn: 0.0223842	total: 58.4s	remaining: 8m 12s
# 111:	learn: 0.0222652	total: 1m 3s	remaining: 8m 21s
# 117:	learn: 0.0221937	total: 1m 3s	remaining: 7m 54s
# 106:	learn: 0.0223688	total: 58.8s	remaining: 8m 10s
# 112:	learn: 0.0222477	total: 1m 3s	remaining: 8m 19s
# 118:	learn: 0.0221726	total: 1m 3s	remaining: 7m 53s
# 107:	learn: 0.0223457	total: 59.2s	remaining: 8m 9s
# 113:	learn: 0.0222348	total: 1m 3s	remaining: 8m 17s
# 119:	learn: 0.0221533	total: 1m 4s	remaining: 7m 51s
# 108:	learn: 0.0223259	total: 59.8s	remaining: 8m 8s
# 114:	learn: 0.0222201	total: 1m 4s	remaining: 8m 15s
# 120:	learn: 0.0221335	total: 1m 4s	remaining: 7m 51s
# 109:	learn: 0.0223067	total: 1m	remaining: 8m 7s
# 115:	learn: 0.0222018	total: 1m 4s	remaining: 8m 14s
# 121:	learn: 0.0221186	total: 1m 5s	remaining: 7m 49s
# 110:	learn: 0.0222866	total: 1m	remaining: 8m 6s
# 116:	learn: 0.0221826	total: 1m 5s	remaining: 8m 13s
# 122:	learn: 0.0221032	total: 1m 5s	remaining: 7m 47s
# 111:	learn: 0.0222688	total: 1m 1s	remaining: 8m 4s
# 117:	learn: 0.0221667	total: 1m 5s	remaining: 8m 11s
# 112:	learn: 0.0222556	total: 1m 1s	remaining: 8m 1s
# 123:	learn: 0.0220860	total: 1m 6s	remaining: 7m 47s
# 118:	learn: 0.0221510	total: 1m 6s	remaining: 8m 10s
# 113:	learn: 0.0222378	total: 1m 1s	remaining: 8m 1s
# 124:	learn: 0.0220690	total: 1m 6s	remaining: 7m 46s
# 119:	learn: 0.0221347	total: 1m 6s	remaining: 8m 9s
# 125:	learn: 0.0220546	total: 1m 6s	remaining: 7m 44s
# 114:	learn: 0.0222206	total: 1m 2s	remaining: 7m 59s
# 126:	learn: 0.0220401	total: 1m 7s	remaining: 7m 42s
# 115:	learn: 0.0222042	total: 1m 2s	remaining: 7m 58s
# 120:	learn: 0.0221183	total: 1m 7s	remaining: 8m 9s
# 116:	learn: 0.0221887	total: 1m 2s	remaining: 7m 55s
# 127:	learn: 0.0220243	total: 1m 7s	remaining: 7m 41s
# 121:	learn: 0.0220977	total: 1m 7s	remaining: 8m 7s
# 117:	learn: 0.0221728	total: 1m 3s	remaining: 7m 53s
# 128:	learn: 0.0220108	total: 1m 8s	remaining: 7m 40s
# 122:	learn: 0.0220831	total: 1m 8s	remaining: 8m 6s
# 118:	learn: 0.0221563	total: 1m 3s	remaining: 7m 52s
# 129:	learn: 0.0219972	total: 1m 8s	remaining: 7m 38s
# 123:	learn: 0.0220678	total: 1m 8s	remaining: 8m 4s
# 130:	learn: 0.0219832	total: 1m 8s	remaining: 7m 36s
# 119:	learn: 0.0221389	total: 1m 4s	remaining: 7m 51s
# 124:	learn: 0.0220517	total: 1m 8s	remaining: 8m 2s
# 131:	learn: 0.0219697	total: 1m 9s	remaining: 7m 35s
# 120:	learn: 0.0221234	total: 1m 4s	remaining: 7m 49s
# 125:	learn: 0.0220348	total: 1m 9s	remaining: 8m 1s
# 132:	learn: 0.0219555	total: 1m 9s	remaining: 7m 34s
# 121:	learn: 0.0221047	total: 1m 5s	remaining: 7m 48s
# 133:	learn: 0.0219430	total: 1m 9s	remaining: 7m 32s
# 126:	learn: 0.0220196	total: 1m 9s	remaining: 8m
# 122:	learn: 0.0220878	total: 1m 5s	remaining: 7m 47s
# 134:	learn: 0.0219311	total: 1m 10s	remaining: 7m 30s
# 127:	learn: 0.0220031	total: 1m 10s	remaining: 7m 58s
# 123:	learn: 0.0220747	total: 1m 5s	remaining: 7m 44s
# 135:	learn: 0.0219165	total: 1m 10s	remaining: 7m 28s
# 128:	learn: 0.0219833	total: 1m 10s	remaining: 7m 57s
# 124:	learn: 0.0220590	total: 1m 6s	remaining: 7m 43s
# 136:	learn: 0.0218966	total: 1m 11s	remaining: 7m 27s
# 129:	learn: 0.0219687	total: 1m 11s	remaining: 7m 55s
# 125:	learn: 0.0220451	total: 1m 6s	remaining: 7m 41s
# 137:	learn: 0.0218836	total: 1m 11s	remaining: 7m 26s
# 130:	learn: 0.0219535	total: 1m 11s	remaining: 7m 54s
# 126:	learn: 0.0220276	total: 1m 6s	remaining: 7m 39s
# 138:	learn: 0.0218718	total: 1m 11s	remaining: 7m 24s
# 131:	learn: 0.0219391	total: 1m 11s	remaining: 7m 52s
# 127:	learn: 0.0220133	total: 1m 7s	remaining: 7m 38s
# 139:	learn: 0.0218581	total: 1m 12s	remaining: 7m 23s
# 132:	learn: 0.0219245	total: 1m 12s	remaining: 7m 51s
# 128:	learn: 0.0220006	total: 1m 7s	remaining: 7m 37s
# 133:	learn: 0.0219108	total: 1m 12s	remaining: 7m 48s
# 140:	learn: 0.0218443	total: 1m 12s	remaining: 7m 22s
# 129:	learn: 0.0219865	total: 1m 8s	remaining: 7m 35s
# 141:	learn: 0.0218326	total: 1m 13s	remaining: 7m 21s
# 134:	learn: 0.0218974	total: 1m 12s	remaining: 7m 47s
# 130:	learn: 0.0219718	total: 1m 8s	remaining: 7m 34s
# 135:	learn: 0.0218850	total: 1m 13s	remaining: 7m 45s
# 142:	learn: 0.0218196	total: 1m 13s	remaining: 7m 20s
# 131:	learn: 0.0219568	total: 1m 8s	remaining: 7m 32s
# 136:	learn: 0.0218713	total: 1m 13s	remaining: 7m 44s
# 132:	learn: 0.0219425	total: 1m 9s	remaining: 7m 31s
# 143:	learn: 0.0218063	total: 1m 13s	remaining: 7m 19s
# 137:	learn: 0.0218553	total: 1m 14s	remaining: 7m 43s
# 133:	learn: 0.0219285	total: 1m 9s	remaining: 7m 30s
# 144:	learn: 0.0217942	total: 1m 14s	remaining: 7m 19s
# 138:	learn: 0.0218421	total: 1m 14s	remaining: 7m 41s
# 134:	learn: 0.0219145	total: 1m 10s	remaining: 7m 29s
# 145:	learn: 0.0217812	total: 1m 14s	remaining: 7m 18s
# 139:	learn: 0.0218291	total: 1m 14s	remaining: 7m 40s
# 146:	learn: 0.0217641	total: 1m 15s	remaining: 7m 17s
# 135:	learn: 0.0218938	total: 1m 10s	remaining: 7m 28s
# 140:	learn: 0.0218163	total: 1m 15s	remaining: 7m 38s
# 136:	learn: 0.0218761	total: 1m 11s	remaining: 7m 27s
# 147:	learn: 0.0217492	total: 1m 15s	remaining: 7m 15s
# 141:	learn: 0.0218032	total: 1m 15s	remaining: 7m 37s
# 148:	learn: 0.0217365	total: 1m 16s	remaining: 7m 14s
# 137:	learn: 0.0218612	total: 1m 11s	remaining: 7m 26s
# 142:	learn: 0.0217886	total: 1m 16s	remaining: 7m 36s
# 149:	learn: 0.0217242	total: 1m 16s	remaining: 7m 13s
# 143:	learn: 0.0217771	total: 1m 16s	remaining: 7m 34s
# 138:	learn: 0.0218471	total: 1m 12s	remaining: 7m 26s
# 150:	learn: 0.0217125	total: 1m 16s	remaining: 7m 12s
# 144:	learn: 0.0217656	total: 1m 16s	remaining: 7m 33s
# 139:	learn: 0.0218344	total: 1m 12s	remaining: 7m 25s
# 151:	learn: 0.0217008	total: 1m 17s	remaining: 7m 10s
# 145:	learn: 0.0217541	total: 1m 17s	remaining: 7m 31s
# 152:	learn: 0.0216869	total: 1m 17s	remaining: 7m 9s
# 146:	learn: 0.0217415	total: 1m 17s	remaining: 7m 29s
# 140:	learn: 0.0218208	total: 1m 12s	remaining: 7m 24s
# 147:	learn: 0.0217284	total: 1m 17s	remaining: 7m 28s
# 141:	learn: 0.0218077	total: 1m 13s	remaining: 7m 23s
# 153:	learn: 0.0216746	total: 1m 18s	remaining: 7m 8s
# 148:	learn: 0.0217176	total: 1m 18s	remaining: 7m 26s
# 142:	learn: 0.0217963	total: 1m 13s	remaining: 7m 22s
# 154:	learn: 0.0216627	total: 1m 18s	remaining: 7m 7s
# 149:	learn: 0.0217051	total: 1m 18s	remaining: 7m 25s
# 155:	learn: 0.0216486	total: 1m 18s	remaining: 7m 6s
# 143:	learn: 0.0217834	total: 1m 14s	remaining: 7m 20s
# 150:	learn: 0.0216929	total: 1m 18s	remaining: 7m 23s
# 144:	learn: 0.0217694	total: 1m 14s	remaining: 7m 20s
# 156:	learn: 0.0216351	total: 1m 19s	remaining: 7m 5s
# 151:	learn: 0.0216805	total: 1m 19s	remaining: 7m 22s
# 145:	learn: 0.0217565	total: 1m 14s	remaining: 7m 18s
# 157:	learn: 0.0216231	total: 1m 19s	remaining: 7m 4s
# 152:	learn: 0.0216691	total: 1m 19s	remaining: 7m 21s
# 158:	learn: 0.0216111	total: 1m 20s	remaining: 7m 3s
# 146:	learn: 0.0217439	total: 1m 15s	remaining: 7m 18s
# 153:	learn: 0.0216580	total: 1m 20s	remaining: 7m 20s
# 159:	learn: 0.0216002	total: 1m 20s	remaining: 7m 2s
# 147:	learn: 0.0217311	total: 1m 15s	remaining: 7m 17s
# 154:	learn: 0.0216447	total: 1m 20s	remaining: 7m 19s
# 160:	learn: 0.0215871	total: 1m 21s	remaining: 7m 2s
# 148:	learn: 0.0217184	total: 1m 16s	remaining: 7m 16s
# 155:	learn: 0.0216330	total: 1m 21s	remaining: 7m 19s
# 149:	learn: 0.0217041	total: 1m 16s	remaining: 7m 15s
# 161:	learn: 0.0215748	total: 1m 21s	remaining: 7m 2s
# 156:	learn: 0.0216231	total: 1m 21s	remaining: 7m 18s
# 162:	learn: 0.0215616	total: 1m 22s	remaining: 7m 1s
# 150:	learn: 0.0216909	total: 1m 17s	remaining: 7m 15s
# 157:	learn: 0.0216097	total: 1m 22s	remaining: 7m 18s
# 163:	learn: 0.0215517	total: 1m 22s	remaining: 7m
# 151:	learn: 0.0216781	total: 1m 18s	remaining: 7m 16s
# 158:	learn: 0.0215991	total: 1m 22s	remaining: 7m 17s
# 164:	learn: 0.0215413	total: 1m 23s	remaining: 7m
# 152:	learn: 0.0216661	total: 1m 18s	remaining: 7m 15s
# 159:	learn: 0.0215885	total: 1m 23s	remaining: 7m 16s
# 165:	learn: 0.0215301	total: 1m 23s	remaining: 7m
# 153:	learn: 0.0216546	total: 1m 19s	remaining: 7m 14s
# 160:	learn: 0.0215760	total: 1m 23s	remaining: 7m 16s
# 166:	learn: 0.0215195	total: 1m 24s	remaining: 6m 59s
# 154:	learn: 0.0216422	total: 1m 19s	remaining: 7m 13s
# 161:	learn: 0.0215649	total: 1m 24s	remaining: 7m 16s
# 167:	learn: 0.0215094	total: 1m 24s	remaining: 6m 59s
# 155:	learn: 0.0216309	total: 1m 20s	remaining: 7m 13s
# 162:	learn: 0.0215530	total: 1m 25s	remaining: 7m 16s
# 168:	learn: 0.0214990	total: 1m 25s	remaining: 6m 58s
# 156:	learn: 0.0216195	total: 1m 20s	remaining: 7m 12s
# 163:	learn: 0.0215431	total: 1m 25s	remaining: 7m 15s
# 157:	learn: 0.0216068	total: 1m 21s	remaining: 7m 11s
# 169:	learn: 0.0214876	total: 1m 25s	remaining: 6m 59s
# 164:	learn: 0.0215338	total: 1m 25s	remaining: 7m 15s
# 158:	learn: 0.0215950	total: 1m 21s	remaining: 7m 11s
# 170:	learn: 0.0214777	total: 1m 26s	remaining: 6m 59s
# 165:	learn: 0.0215235	total: 1m 26s	remaining: 7m 15s
# 159:	learn: 0.0215840	total: 1m 22s	remaining: 7m 12s
# 171:	learn: 0.0214683	total: 1m 27s	remaining: 6m 59s
# 160:	learn: 0.0215730	total: 1m 22s	remaining: 7m 11s
# 166:	learn: 0.0215084	total: 1m 27s	remaining: 7m 15s
# 172:	learn: 0.0214578	total: 1m 27s	remaining: 6m 58s
# 161:	learn: 0.0215631	total: 1m 23s	remaining: 7m 10s
# 173:	learn: 0.0214488	total: 1m 28s	remaining: 6m 58s
# 167:	learn: 0.0214968	total: 1m 28s	remaining: 7m 15s
# 162:	learn: 0.0215527	total: 1m 23s	remaining: 7m 10s
# 168:	learn: 0.0214858	total: 1m 28s	remaining: 7m 15s
# 174:	learn: 0.0214383	total: 1m 28s	remaining: 6m 58s
# 163:	learn: 0.0215409	total: 1m 24s	remaining: 7m 8s
# 169:	learn: 0.0214745	total: 1m 29s	remaining: 7m 14s
# 175:	learn: 0.0214291	total: 1m 29s	remaining: 6m 58s
# 164:	learn: 0.0215264	total: 1m 24s	remaining: 7m 8s
# 170:	learn: 0.0214642	total: 1m 29s	remaining: 7m 13s
# 176:	learn: 0.0214187	total: 1m 29s	remaining: 6m 58s
# 165:	learn: 0.0215160	total: 1m 25s	remaining: 7m 8s
# 171:	learn: 0.0214547	total: 1m 30s	remaining: 7m 13s
# 166:	learn: 0.0215054	total: 1m 25s	remaining: 7m 7s
# 177:	learn: 0.0214093	total: 1m 30s	remaining: 6m 57s
# 172:	learn: 0.0214447	total: 1m 30s	remaining: 7m 12s
# 167:	learn: 0.0214958	total: 1m 26s	remaining: 7m 6s
# 178:	learn: 0.0213992	total: 1m 30s	remaining: 6m 57s
# 173:	learn: 0.0214358	total: 1m 30s	remaining: 7m 11s
# 168:	learn: 0.0214859	total: 1m 26s	remaining: 7m 6s
# 179:	learn: 0.0213891	total: 1m 31s	remaining: 6m 56s
# 174:	learn: 0.0214275	total: 1m 31s	remaining: 7m 11s
# 169:	learn: 0.0214753	total: 1m 27s	remaining: 7m 5s
# 180:	learn: 0.0213800	total: 1m 32s	remaining: 6m 56s
# 175:	learn: 0.0214172	total: 1m 32s	remaining: 7m 10s
# 170:	learn: 0.0214654	total: 1m 27s	remaining: 7m 4s
# 171:	learn: 0.0214538	total: 1m 27s	remaining: 7m 3s
# 181:	learn: 0.0213705	total: 1m 32s	remaining: 6m 56s
# 176:	learn: 0.0214057	total: 1m 32s	remaining: 7m 10s
# 172:	learn: 0.0214437	total: 1m 28s	remaining: 7m 2s
# 182:	learn: 0.0213619	total: 1m 33s	remaining: 6m 55s
# 177:	learn: 0.0213968	total: 1m 33s	remaining: 7m 10s
# 183:	learn: 0.0213524	total: 1m 33s	remaining: 6m 55s
# 173:	learn: 0.0214332	total: 1m 29s	remaining: 7m 2s
# 178:	learn: 0.0213871	total: 1m 33s	remaining: 7m 10s
# 184:	learn: 0.0213437	total: 1m 34s	remaining: 6m 54s
# 174:	learn: 0.0214226	total: 1m 29s	remaining: 7m 2s
# 179:	learn: 0.0213780	total: 1m 34s	remaining: 7m 9s
# 185:	learn: 0.0213349	total: 1m 34s	remaining: 6m 54s
# 175:	learn: 0.0214113	total: 1m 29s	remaining: 7m 1s
# 180:	learn: 0.0213681	total: 1m 34s	remaining: 7m 8s
# 186:	learn: 0.0213265	total: 1m 35s	remaining: 6m 53s
# 176:	learn: 0.0214025	total: 1m 30s	remaining: 7m
# 181:	learn: 0.0213586	total: 1m 35s	remaining: 7m 8s
# 187:	learn: 0.0213185	total: 1m 35s	remaining: 6m 52s
# 177:	learn: 0.0213926	total: 1m 31s	remaining: 7m
# 188:	learn: 0.0213092	total: 1m 35s	remaining: 6m 51s
# 182:	learn: 0.0213481	total: 1m 35s	remaining: 7m 7s
# 178:	learn: 0.0213832	total: 1m 31s	remaining: 6m 59s
# 189:	learn: 0.0212953	total: 1m 36s	remaining: 6m 51s
# 183:	learn: 0.0213384	total: 1m 36s	remaining: 7m 7s
# 179:	learn: 0.0213735	total: 1m 31s	remaining: 6m 59s
# 190:	learn: 0.0212869	total: 1m 36s	remaining: 6m 50s
# 184:	learn: 0.0213285	total: 1m 36s	remaining: 7m 6s
# 180:	learn: 0.0213647	total: 1m 32s	remaining: 6m 58s
# 191:	learn: 0.0212772	total: 1m 37s	remaining: 6m 49s
# 185:	learn: 0.0213174	total: 1m 37s	remaining: 7m 6s
# 181:	learn: 0.0213548	total: 1m 32s	remaining: 6m 57s
# 192:	learn: 0.0212695	total: 1m 37s	remaining: 6m 49s
# 182:	learn: 0.0213469	total: 1m 33s	remaining: 6m 57s
# 186:	learn: 0.0213077	total: 1m 38s	remaining: 7m 6s
# 193:	learn: 0.0212619	total: 1m 38s	remaining: 6m 48s
# 183:	learn: 0.0213383	total: 1m 33s	remaining: 6m 56s
# 187:	learn: 0.0212984	total: 1m 38s	remaining: 7m 5s
# 184:	learn: 0.0213281	total: 1m 34s	remaining: 6m 55s
# 194:	learn: 0.0212536	total: 1m 39s	remaining: 6m 48s
# 188:	learn: 0.0212912	total: 1m 38s	remaining: 7m 4s
# 185:	learn: 0.0213206	total: 1m 34s	remaining: 6m 54s
# 189:	learn: 0.0212821	total: 1m 39s	remaining: 7m 4s
# 195:	learn: 0.0212444	total: 1m 39s	remaining: 6m 48s
# 186:	learn: 0.0213110	total: 1m 35s	remaining: 6m 54s
# 196:	learn: 0.0212365	total: 1m 40s	remaining: 6m 47s
# 190:	learn: 0.0212725	total: 1m 40s	remaining: 7m 3s
# 191:	learn: 0.0212646	total: 1m 40s	remaining: 7m 2s
# 197:	learn: 0.0212281	total: 1m 40s	remaining: 6m 47s
# 187:	learn: 0.0213017	total: 1m 35s	remaining: 6m 53s
# 198:	learn: 0.0212198	total: 1m 40s	remaining: 6m 45s
# 192:	learn: 0.0212563	total: 1m 40s	remaining: 7m 1s
# 188:	learn: 0.0212918	total: 1m 36s	remaining: 6m 53s
# 199:	learn: 0.0212063	total: 1m 41s	remaining: 6m 45s
# 193:	learn: 0.0212486	total: 1m 41s	remaining: 7m
# 189:	learn: 0.0212810	total: 1m 36s	remaining: 6m 52s
# 200:	learn: 0.0211975	total: 1m 41s	remaining: 6m 43s
# 194:	learn: 0.0212416	total: 1m 41s	remaining: 6m 59s
# 201:	learn: 0.0211898	total: 1m 41s	remaining: 6m 42s
# 190:	learn: 0.0212730	total: 1m 37s	remaining: 6m 52s
# 195:	learn: 0.0212338	total: 1m 41s	remaining: 6m 57s
# 202:	learn: 0.0211831	total: 1m 42s	remaining: 6m 41s
# 191:	learn: 0.0212644	total: 1m 37s	remaining: 6m 51s
# 196:	learn: 0.0212261	total: 1m 42s	remaining: 6m 56s
# 203:	learn: 0.0211758	total: 1m 42s	remaining: 6m 40s
# 197:	learn: 0.0212181	total: 1m 42s	remaining: 6m 55s
# 192:	learn: 0.0212559	total: 1m 38s	remaining: 6m 50s
# 204:	learn: 0.0211696	total: 1m 42s	remaining: 6m 39s
# 193:	learn: 0.0212464	total: 1m 38s	remaining: 6m 49s
# 198:	learn: 0.0212100	total: 1m 43s	remaining: 6m 54s
# 205:	learn: 0.0211631	total: 1m 43s	remaining: 6m 37s
# 194:	learn: 0.0212380	total: 1m 38s	remaining: 6m 48s
# 199:	learn: 0.0212013	total: 1m 43s	remaining: 6m 54s
# 206:	learn: 0.0211555	total: 1m 43s	remaining: 6m 37s
# 195:	learn: 0.0212292	total: 1m 39s	remaining: 6m 46s
# 207:	learn: 0.0211467	total: 1m 43s	remaining: 6m 35s
# 200:	learn: 0.0211939	total: 1m 43s	remaining: 6m 53s
# 196:	learn: 0.0212210	total: 1m 39s	remaining: 6m 45s
# 201:	learn: 0.0211858	total: 1m 44s	remaining: 6m 52s
# 208:	learn: 0.0211374	total: 1m 44s	remaining: 6m 35s
# 197:	learn: 0.0212137	total: 1m 39s	remaining: 6m 44s
# 198:	learn: 0.0212051	total: 1m 40s	remaining: 6m 43s
# 202:	learn: 0.0211782	total: 1m 44s	remaining: 6m 51s
# 209:	learn: 0.0211286	total: 1m 44s	remaining: 6m 34s
# 199:	learn: 0.0211940	total: 1m 40s	remaining: 6m 42s
# 203:	learn: 0.0211710	total: 1m 45s	remaining: 6m 50s
# 210:	learn: 0.0211208	total: 1m 45s	remaining: 6m 33s
# 211:	learn: 0.0211143	total: 1m 45s	remaining: 6m 32s
# 204:	learn: 0.0211626	total: 1m 45s	remaining: 6m 49s
# 200:	learn: 0.0211848	total: 1m 41s	remaining: 6m 41s
# 205:	learn: 0.0211519	total: 1m 45s	remaining: 6m 48s
# 212:	learn: 0.0211052	total: 1m 46s	remaining: 6m 31s
# 201:	learn: 0.0211766	total: 1m 41s	remaining: 6m 40s
# 206:	learn: 0.0211442	total: 1m 46s	remaining: 6m 47s
# 213:	learn: 0.0210966	total: 1m 46s	remaining: 6m 30s
# 202:	learn: 0.0211684	total: 1m 41s	remaining: 6m 40s
# 207:	learn: 0.0211366	total: 1m 46s	remaining: 6m 45s
# 214:	learn: 0.0210890	total: 1m 46s	remaining: 6m 30s
# 203:	learn: 0.0211603	total: 1m 42s	remaining: 6m 38s
# 208:	learn: 0.0211276	total: 1m 46s	remaining: 6m 44s
# 215:	learn: 0.0210812	total: 1m 47s	remaining: 6m 29s
# 204:	learn: 0.0211523	total: 1m 42s	remaining: 6m 38s
# 216:	learn: 0.0210739	total: 1m 47s	remaining: 6m 28s
# 205:	learn: 0.0211448	total: 1m 42s	remaining: 6m 36s
# 209:	learn: 0.0211201	total: 1m 47s	remaining: 6m 44s
# 217:	learn: 0.0210659	total: 1m 48s	remaining: 6m 27s
# 210:	learn: 0.0211133	total: 1m 47s	remaining: 6m 43s
# 206:	learn: 0.0211370	total: 1m 43s	remaining: 6m 36s
# 218:	learn: 0.0210566	total: 1m 48s	remaining: 6m 26s
# 207:	learn: 0.0211289	total: 1m 43s	remaining: 6m 35s
# 211:	learn: 0.0211055	total: 1m 48s	remaining: 6m 43s
# 208:	learn: 0.0211218	total: 1m 44s	remaining: 6m 34s
# 219:	learn: 0.0210496	total: 1m 48s	remaining: 6m 25s
# 212:	learn: 0.0210988	total: 1m 48s	remaining: 6m 42s
# 220:	learn: 0.0210416	total: 1m 49s	remaining: 6m 25s
# 209:	learn: 0.0211147	total: 1m 44s	remaining: 6m 33s
# 213:	learn: 0.0210912	total: 1m 49s	remaining: 6m 41s
# 210:	learn: 0.0211077	total: 1m 44s	remaining: 6m 32s
# 221:	learn: 0.0210345	total: 1m 49s	remaining: 6m 24s
# 214:	learn: 0.0210817	total: 1m 49s	remaining: 6m 40s
# 211:	learn: 0.0210991	total: 1m 45s	remaining: 6m 31s
# 222:	learn: 0.0210270	total: 1m 50s	remaining: 6m 23s
# 215:	learn: 0.0210744	total: 1m 50s	remaining: 6m 39s
# 212:	learn: 0.0210911	total: 1m 45s	remaining: 6m 30s
# 223:	learn: 0.0210201	total: 1m 50s	remaining: 6m 23s
# 216:	learn: 0.0210652	total: 1m 50s	remaining: 6m 39s
# 213:	learn: 0.0210822	total: 1m 46s	remaining: 6m 29s
# 224:	learn: 0.0210140	total: 1m 50s	remaining: 6m 22s
# 217:	learn: 0.0210574	total: 1m 50s	remaining: 6m 38s
# 214:	learn: 0.0210752	total: 1m 46s	remaining: 6m 29s
# 225:	learn: 0.0210051	total: 1m 51s	remaining: 6m 21s
# 218:	learn: 0.0210488	total: 1m 51s	remaining: 6m 37s
# 215:	learn: 0.0210683	total: 1m 47s	remaining: 6m 28s
# 226:	learn: 0.0209980	total: 1m 51s	remaining: 6m 20s
# 219:	learn: 0.0210416	total: 1m 51s	remaining: 6m 36s
# 227:	learn: 0.0209913	total: 1m 52s	remaining: 6m 19s
# 216:	learn: 0.0210592	total: 1m 47s	remaining: 6m 27s
# 220:	learn: 0.0210343	total: 1m 52s	remaining: 6m 35s
# 217:	learn: 0.0210524	total: 1m 47s	remaining: 6m 26s
# 228:	learn: 0.0209846	total: 1m 52s	remaining: 6m 19s
# 221:	learn: 0.0210265	total: 1m 52s	remaining: 6m 34s
# 218:	learn: 0.0210445	total: 1m 48s	remaining: 6m 25s
# 222:	learn: 0.0210210	total: 1m 52s	remaining: 6m 33s
# 229:	learn: 0.0209782	total: 1m 53s	remaining: 6m 18s
# 219:	learn: 0.0210375	total: 1m 48s	remaining: 6m 24s
# 223:	learn: 0.0210148	total: 1m 53s	remaining: 6m 31s
# 230:	learn: 0.0209715	total: 1m 53s	remaining: 6m 17s
# 224:	learn: 0.0210089	total: 1m 53s	remaining: 6m 30s
# 220:	learn: 0.0210311	total: 1m 48s	remaining: 6m 24s
# 231:	learn: 0.0209658	total: 1m 53s	remaining: 6m 16s
# 221:	learn: 0.0210243	total: 1m 49s	remaining: 6m 23s
# 225:	learn: 0.0210011	total: 1m 53s	remaining: 6m 30s
# 232:	learn: 0.0209604	total: 1m 54s	remaining: 6m 16s
# 222:	learn: 0.0210177	total: 1m 49s	remaining: 6m 21s
# 226:	learn: 0.0209945	total: 1m 54s	remaining: 6m 29s
# 223:	learn: 0.0210122	total: 1m 49s	remaining: 6m 20s
# 233:	learn: 0.0209538	total: 1m 54s	remaining: 6m 15s
# 227:	learn: 0.0209877	total: 1m 54s	remaining: 6m 28s
# 224:	learn: 0.0210058	total: 1m 50s	remaining: 6m 19s
# 234:	learn: 0.0209474	total: 1m 55s	remaining: 6m 14s
# 228:	learn: 0.0209815	total: 1m 55s	remaining: 6m 27s
# 235:	learn: 0.0209414	total: 1m 55s	remaining: 6m 13s
# 225:	learn: 0.0209987	total: 1m 50s	remaining: 6m 18s
# 229:	learn: 0.0209753	total: 1m 55s	remaining: 6m 26s
# 236:	learn: 0.0209329	total: 1m 55s	remaining: 6m 12s
# 226:	learn: 0.0209919	total: 1m 51s	remaining: 6m 18s
# 230:	learn: 0.0209680	total: 1m 55s	remaining: 6m 26s
# 237:	learn: 0.0209268	total: 1m 56s	remaining: 6m 11s
# 227:	learn: 0.0209852	total: 1m 51s	remaining: 6m 17s
# 231:	learn: 0.0209606	total: 1m 56s	remaining: 6m 25s
# 238:	learn: 0.0209217	total: 1m 56s	remaining: 6m 11s
# 228:	learn: 0.0209794	total: 1m 51s	remaining: 6m 16s
# 229:	learn: 0.0209727	total: 1m 52s	remaining: 6m 15s
# 232:	learn: 0.0209548	total: 1m 56s	remaining: 6m 24s
# 239:	learn: 0.0209157	total: 1m 56s	remaining: 6m 10s
# 233:	learn: 0.0209489	total: 1m 57s	remaining: 6m 23s
# 240:	learn: 0.0209098	total: 1m 57s	remaining: 6m 9s
# 230:	learn: 0.0209637	total: 1m 52s	remaining: 6m 15s
# 234:	learn: 0.0209429	total: 1m 57s	remaining: 6m 22s
# 241:	learn: 0.0209028	total: 1m 57s	remaining: 6m 8s
# 231:	learn: 0.0209574	total: 1m 53s	remaining: 6m 14s
# 242:	learn: 0.0208965	total: 1m 58s	remaining: 6m 8s
# 235:	learn: 0.0209367	total: 1m 58s	remaining: 6m 22s
# 232:	learn: 0.0209508	total: 1m 53s	remaining: 6m 13s
# 243:	learn: 0.0208899	total: 1m 58s	remaining: 6m 7s
# 236:	learn: 0.0209287	total: 1m 58s	remaining: 6m 21s
# 233:	learn: 0.0209435	total: 1m 53s	remaining: 6m 12s
# 237:	learn: 0.0209225	total: 1m 58s	remaining: 6m 20s
# 244:	learn: 0.0208843	total: 1m 58s	remaining: 6m 6s
# 234:	learn: 0.0209363	total: 1m 54s	remaining: 6m 12s
# 238:	learn: 0.0209166	total: 1m 59s	remaining: 6m 19s
# 245:	learn: 0.0208786	total: 1m 59s	remaining: 6m 5s
# 235:	learn: 0.0209295	total: 1m 54s	remaining: 6m 11s
# 239:	learn: 0.0209095	total: 1m 59s	remaining: 6m 18s
# 246:	learn: 0.0208729	total: 1m 59s	remaining: 6m 5s
# 236:	learn: 0.0209223	total: 1m 55s	remaining: 6m 10s
# 240:	learn: 0.0209031	total: 1m 59s	remaining: 6m 17s
# 237:	learn: 0.0209165	total: 1m 55s	remaining: 6m 9s
# 247:	learn: 0.0208672	total: 2m	remaining: 6m 4s
# 241:	learn: 0.0208979	total: 2m	remaining: 6m 16s
# 248:	learn: 0.0208613	total: 2m	remaining: 6m 3s
# 238:	learn: 0.0209087	total: 1m 55s	remaining: 6m 9s
# 242:	learn: 0.0208921	total: 2m	remaining: 6m 15s
# 249:	learn: 0.0208562	total: 2m 1s	remaining: 6m 3s
# 243:	learn: 0.0208848	total: 2m 1s	remaining: 6m 15s
# 239:	learn: 0.0209012	total: 1m 56s	remaining: 6m 9s
# 250:	learn: 0.0208484	total: 2m 1s	remaining: 6m 2s
# 240:	learn: 0.0208954	total: 1m 56s	remaining: 6m 7s
# 244:	learn: 0.0208786	total: 2m 1s	remaining: 6m 14s
# 251:	learn: 0.0208434	total: 2m 1s	remaining: 6m 1s
# 241:	learn: 0.0208895	total: 1m 57s	remaining: 6m 7s
# 245:	learn: 0.0208732	total: 2m 1s	remaining: 6m 13s
# 252:	learn: 0.0208372	total: 2m 2s	remaining: 6m
# 246:	learn: 0.0208682	total: 2m 2s	remaining: 6m 12s
# 242:	learn: 0.0208832	total: 1m 57s	remaining: 6m 6s
# 247:	learn: 0.0208624	total: 2m 2s	remaining: 6m 11s
# 243:	learn: 0.0208773	total: 1m 57s	remaining: 6m 5s
# 253:	learn: 0.0208294	total: 2m 2s	remaining: 6m
# 244:	learn: 0.0208699	total: 1m 58s	remaining: 6m 4s
# 248:	learn: 0.0208564	total: 2m 2s	remaining: 6m 10s
# 254:	learn: 0.0208221	total: 2m 3s	remaining: 5m 59s
# 245:	learn: 0.0208645	total: 1m 58s	remaining: 6m 3s
# 255:	learn: 0.0208171	total: 2m 3s	remaining: 5m 58s
# 249:	learn: 0.0208509	total: 2m 3s	remaining: 6m 9s
# 246:	learn: 0.0208589	total: 1m 58s	remaining: 6m 2s
# 256:	learn: 0.0208118	total: 2m 3s	remaining: 5m 57s
# 250:	learn: 0.0208442	total: 2m 3s	remaining: 6m 9s
# 247:	learn: 0.0208516	total: 1m 59s	remaining: 6m 1s
# 257:	learn: 0.0208054	total: 2m 4s	remaining: 5m 56s
# 251:	learn: 0.0208388	total: 2m 4s	remaining: 6m 8s
# 248:	learn: 0.0208462	total: 1m 59s	remaining: 6m
# 258:	learn: 0.0208002	total: 2m 4s	remaining: 5m 56s
# 252:	learn: 0.0208333	total: 2m 4s	remaining: 6m 7s
# 249:	learn: 0.0208406	total: 2m	remaining: 6m
# 253:	learn: 0.0208276	total: 2m 4s	remaining: 6m 6s
# 259:	learn: 0.0207932	total: 2m 5s	remaining: 5m 55s
# 250:	learn: 0.0208347	total: 2m	remaining: 5m 59s
# 260:	learn: 0.0207882	total: 2m 5s	remaining: 5m 54s
# 254:	learn: 0.0208223	total: 2m 5s	remaining: 6m 5s
# 251:	learn: 0.0208292	total: 2m	remaining: 5m 59s
# 261:	learn: 0.0207812	total: 2m 5s	remaining: 5m 54s
# 255:	learn: 0.0208160	total: 2m 5s	remaining: 6m 5s
# 252:	learn: 0.0208239	total: 2m 1s	remaining: 5m 58s
# 262:	learn: 0.0207751	total: 2m 6s	remaining: 5m 53s
# 256:	learn: 0.0208108	total: 2m 6s	remaining: 6m 4s
# 263:	learn: 0.0207691	total: 2m 6s	remaining: 5m 52s
# 253:	learn: 0.0208179	total: 2m 1s	remaining: 5m 58s
# 264:	learn: 0.0207639	total: 2m 6s	remaining: 5m 51s
# 257:	learn: 0.0208037	total: 2m 6s	remaining: 6m 4s
# 254:	learn: 0.0208131	total: 2m 2s	remaining: 5m 57s
# 258:	learn: 0.0207978	total: 2m 6s	remaining: 6m 3s
# 265:	learn: 0.0207583	total: 2m 7s	remaining: 5m 50s
# 255:	learn: 0.0208067	total: 2m 2s	remaining: 5m 56s
# 259:	learn: 0.0207926	total: 2m 7s	remaining: 6m 2s
# 266:	learn: 0.0207517	total: 2m 7s	remaining: 5m 50s
# 256:	learn: 0.0207999	total: 2m 3s	remaining: 5m 55s
# 260:	learn: 0.0207861	total: 2m 7s	remaining: 6m 1s
# 267:	learn: 0.0207465	total: 2m 7s	remaining: 5m 49s
# 257:	learn: 0.0207945	total: 2m 3s	remaining: 5m 54s
# 261:	learn: 0.0207796	total: 2m 8s	remaining: 6m
# 268:	learn: 0.0207405	total: 2m 8s	remaining: 5m 49s
# 262:	learn: 0.0207737	total: 2m 8s	remaining: 5m 59s
# 258:	learn: 0.0207889	total: 2m 3s	remaining: 5m 54s
# 259:	learn: 0.0207836	total: 2m 4s	remaining: 5m 53s
# 263:	learn: 0.0207679	total: 2m 8s	remaining: 5m 58s
# 269:	learn: 0.0207343	total: 2m 9s	remaining: 5m 48s
# 260:	learn: 0.0207782	total: 2m 4s	remaining: 5m 52s
# 270:	learn: 0.0207290	total: 2m 9s	remaining: 5m 47s
# 264:	learn: 0.0207622	total: 2m 9s	remaining: 5m 58s
# 261:	learn: 0.0207733	total: 2m 4s	remaining: 5m 51s
# 265:	learn: 0.0207572	total: 2m 9s	remaining: 5m 57s
# 271:	learn: 0.0207240	total: 2m 9s	remaining: 5m 47s
# 266:	learn: 0.0207526	total: 2m 9s	remaining: 5m 56s
# 262:	learn: 0.0207682	total: 2m 5s	remaining: 5m 51s
# 272:	learn: 0.0207191	total: 2m 10s	remaining: 5m 46s
# 267:	learn: 0.0207479	total: 2m 10s	remaining: 5m 55s
# 263:	learn: 0.0207630	total: 2m 5s	remaining: 5m 50s
# 273:	learn: 0.0207141	total: 2m 10s	remaining: 5m 45s
# 264:	learn: 0.0207581	total: 2m 5s	remaining: 5m 49s
# 268:	learn: 0.0207432	total: 2m 10s	remaining: 5m 54s
# 274:	learn: 0.0207087	total: 2m 10s	remaining: 5m 44s
# 265:	learn: 0.0207529	total: 2m 6s	remaining: 5m 48s
# 269:	learn: 0.0207385	total: 2m 10s	remaining: 5m 54s
# 275:	learn: 0.0207044	total: 2m 11s	remaining: 5m 44s
# 266:	learn: 0.0207463	total: 2m 6s	remaining: 5m 47s
# 270:	learn: 0.0207337	total: 2m 11s	remaining: 5m 53s
# 276:	learn: 0.0206993	total: 2m 11s	remaining: 5m 43s
# 267:	learn: 0.0207405	total: 2m 7s	remaining: 5m 46s
# 271:	learn: 0.0207280	total: 2m 11s	remaining: 5m 52s
# 277:	learn: 0.0206950	total: 2m 11s	remaining: 5m 42s
# 268:	learn: 0.0207338	total: 2m 7s	remaining: 5m 46s
# 272:	learn: 0.0207231	total: 2m 12s	remaining: 5m 51s
# 278:	learn: 0.0206899	total: 2m 12s	remaining: 5m 42s
# 269:	learn: 0.0207282	total: 2m 7s	remaining: 5m 45s
# 273:	learn: 0.0207185	total: 2m 12s	remaining: 5m 50s
# 274:	learn: 0.0207130	total: 2m 12s	remaining: 5m 49s
# 279:	learn: 0.0206847	total: 2m 12s	remaining: 5m 41s
# 270:	learn: 0.0207231	total: 2m 8s	remaining: 5m 44s
# 275:	learn: 0.0207065	total: 2m 13s	remaining: 5m 48s
# 271:	learn: 0.0207178	total: 2m 8s	remaining: 5m 44s
# 280:	learn: 0.0206784	total: 2m 13s	remaining: 5m 41s
# 276:	learn: 0.0207019	total: 2m 13s	remaining: 5m 48s
# 281:	learn: 0.0206739	total: 2m 13s	remaining: 5m 40s
# 277:	learn: 0.0206967	total: 2m 13s	remaining: 5m 47s
# 272:	learn: 0.0207131	total: 2m 9s	remaining: 5m 43s
# 282:	learn: 0.0206694	total: 2m 14s	remaining: 5m 39s
# 273:	learn: 0.0207085	total: 2m 9s	remaining: 5m 43s
# 278:	learn: 0.0206916	total: 2m 14s	remaining: 5m 46s
# 283:	learn: 0.0206643	total: 2m 14s	remaining: 5m 39s
# 274:	learn: 0.0207031	total: 2m 9s	remaining: 5m 42s
# 279:	learn: 0.0206864	total: 2m 14s	remaining: 5m 45s
# 280:	learn: 0.0206818	total: 2m 14s	remaining: 5m 45s
# 284:	learn: 0.0206591	total: 2m 14s	remaining: 5m 38s
# 275:	learn: 0.0206976	total: 2m 10s	remaining: 5m 42s
# 285:	learn: 0.0206545	total: 2m 15s	remaining: 5m 37s
# 281:	learn: 0.0206769	total: 2m 15s	remaining: 5m 44s
# 276:	learn: 0.0206930	total: 2m 10s	remaining: 5m 41s
# 282:	learn: 0.0206715	total: 2m 15s	remaining: 5m 43s
# 286:	learn: 0.0206496	total: 2m 15s	remaining: 5m 37s
# 277:	learn: 0.0206875	total: 2m 11s	remaining: 5m 40s
# 287:	learn: 0.0206443	total: 2m 16s	remaining: 5m 36s
# 283:	learn: 0.0206668	total: 2m 16s	remaining: 5m 42s
# ...
# 696:	learn: 0.0197646	total: 2m 19s	remaining: 1m
# 697:	learn: 0.0197636	total: 2m 20s	remaining: 1m
# 698:	learn: 0.0197629	total: 2m 20s	remaining: 1m
# 699:	learn: 0.0197621	total: 2m 20s	remaining: 1m
# 700:	learn: 0.0197613	total: 2m 20s	remaining: 60s
# 701:	learn: 0.0197606	total: 2m 20s	remaining: 59.7s
# 702:	learn: 0.0197597	total: 2m 20s	remaining: 59.5s
# 703:	learn: 0.0197590	total: 2m 21s	remaining: 59.3s
# 704:	learn: 0.0197583	total: 2m 21s	remaining: 59.1s
# 705:	learn: 0.0197574	total: 2m 21s	remaining: 58.9s
# 706:	learn: 0.0197564	total: 2m 21s	remaining: 58.7s
# 707:	learn: 0.0197557	total: 2m 21s	remaining: 58.5s
# 708:	learn: 0.0197550	total: 2m 21s	remaining: 58.3s
# 709:	learn: 0.0197540	total: 2m 22s	remaining: 58.1s
# 710:	learn: 0.0197533	total: 2m 22s	remaining: 57.9s
# 711:	learn: 0.0197525	total: 2m 22s	remaining: 57.6s
# 712:	learn: 0.0197519	total: 2m 22s	remaining: 57.4s
# 713:	learn: 0.0197511	total: 2m 22s	remaining: 57.2s
# 714:	learn: 0.0197502	total: 2m 23s	remaining: 57s
# 715:	learn: 0.0197496	total: 2m 23s	remaining: 56.8s
# 716:	learn: 0.0197489	total: 2m 23s	remaining: 56.6s
# 717:	learn: 0.0197480	total: 2m 23s	remaining: 56.4s
# 718:	learn: 0.0197472	total: 2m 23s	remaining: 56.2s
# 719:	learn: 0.0197463	total: 2m 24s	remaining: 56s
# 720:	learn: 0.0197455	total: 2m 24s	remaining: 55.8s
# 721:	learn: 0.0197447	total: 2m 24s	remaining: 55.6s
# 722:	learn: 0.0197440	total: 2m 24s	remaining: 55.4s
# 723:	learn: 0.0197434	total: 2m 24s	remaining: 55.2s
# 724:	learn: 0.0197425	total: 2m 24s	remaining: 55s
# 725:	learn: 0.0197419	total: 2m 25s	remaining: 54.8s
# 726:	learn: 0.0197408	total: 2m 25s	remaining: 54.6s
# 727:	learn: 0.0197401	total: 2m 25s	remaining: 54.4s
# 728:	learn: 0.0197392	total: 2m 25s	remaining: 54.2s
# 729:	learn: 0.0197383	total: 2m 26s	remaining: 54s
# 730:	learn: 0.0197374	total: 2m 26s	remaining: 53.8s
# 731:	learn: 0.0197368	total: 2m 26s	remaining: 53.6s
# 732:	learn: 0.0197360	total: 2m 26s	remaining: 53.4s
# 733:	learn: 0.0197354	total: 2m 26s	remaining: 53.2s
# 734:	learn: 0.0197347	total: 2m 26s	remaining: 53s
# 735:	learn: 0.0197339	total: 2m 27s	remaining: 52.7s
# 736:	learn: 0.0197332	total: 2m 27s	remaining: 52.5s
# 737:	learn: 0.0197324	total: 2m 27s	remaining: 52.3s
# 738:	learn: 0.0197318	total: 2m 27s	remaining: 52.1s
# 739:	learn: 0.0197305	total: 2m 27s	remaining: 51.9s
# 740:	learn: 0.0197299	total: 2m 27s	remaining: 51.7s
# 741:	learn: 0.0197291	total: 2m 27s	remaining: 51.4s
# 742:	learn: 0.0197281	total: 2m 28s	remaining: 51.2s
# 743:	learn: 0.0197274	total: 2m 28s	remaining: 51s
# 744:	learn: 0.0197267	total: 2m 28s	remaining: 50.8s
# 745:	learn: 0.0197261	total: 2m 28s	remaining: 50.6s
# 746:	learn: 0.0197255	total: 2m 28s	remaining: 50.4s
# 747:	learn: 0.0197249	total: 2m 28s	remaining: 50.2s
# 748:	learn: 0.0197240	total: 2m 29s	remaining: 50s
# 749:	learn: 0.0197233	total: 2m 29s	remaining: 49.8s
# 750:	learn: 0.0197226	total: 2m 29s	remaining: 49.6s
# 751:	learn: 0.0197219	total: 2m 29s	remaining: 49.4s
# 752:	learn: 0.0197213	total: 2m 29s	remaining: 49.1s
# 753:	learn: 0.0197206	total: 2m 29s	remaining: 48.9s
# 754:	learn: 0.0197200	total: 2m 30s	remaining: 48.7s
# 755:	learn: 0.0197192	total: 2m 30s	remaining: 48.5s
# 756:	learn: 0.0197186	total: 2m 30s	remaining: 48.3s
# 757:	learn: 0.0197179	total: 2m 30s	remaining: 48.1s
# 758:	learn: 0.0197173	total: 2m 30s	remaining: 47.9s
# 759:	learn: 0.0197168	total: 2m 31s	remaining: 47.7s
# 760:	learn: 0.0197161	total: 2m 31s	remaining: 47.5s
# 761:	learn: 0.0197155	total: 2m 31s	remaining: 47.3s
# 762:	learn: 0.0197148	total: 2m 31s	remaining: 47.1s
# 763:	learn: 0.0197140	total: 2m 31s	remaining: 46.9s
# 764:	learn: 0.0197134	total: 2m 31s	remaining: 46.7s
# 765:	learn: 0.0197128	total: 2m 32s	remaining: 46.5s
# 766:	learn: 0.0197120	total: 2m 32s	remaining: 46.2s
# 767:	learn: 0.0197112	total: 2m 32s	remaining: 46s
# 768:	learn: 0.0197107	total: 2m 32s	remaining: 45.8s
# 769:	learn: 0.0197100	total: 2m 32s	remaining: 45.6s
# 770:	learn: 0.0197093	total: 2m 32s	remaining: 45.4s
# 771:	learn: 0.0197086	total: 2m 33s	remaining: 45.2s
# 772:	learn: 0.0197080	total: 2m 33s	remaining: 45s
# 773:	learn: 0.0197071	total: 2m 33s	remaining: 44.8s
# 774:	learn: 0.0197064	total: 2m 33s	remaining: 44.6s
# 775:	learn: 0.0197058	total: 2m 33s	remaining: 44.4s
# 776:	learn: 0.0197049	total: 2m 34s	remaining: 44.2s
# 777:	learn: 0.0197041	total: 2m 34s	remaining: 44s
# 778:	learn: 0.0197035	total: 2m 34s	remaining: 43.8s
# 779:	learn: 0.0197029	total: 2m 34s	remaining: 43.6s
# 780:	learn: 0.0197021	total: 2m 34s	remaining: 43.4s
# 781:	learn: 0.0197014	total: 2m 35s	remaining: 43.2s
# 782:	learn: 0.0197008	total: 2m 35s	remaining: 43s
# 783:	learn: 0.0197001	total: 2m 35s	remaining: 42.8s
# 784:	learn: 0.0196995	total: 2m 35s	remaining: 42.6s
# 785:	learn: 0.0196986	total: 2m 35s	remaining: 42.4s
# 786:	learn: 0.0196980	total: 2m 35s	remaining: 42.2s
# 787:	learn: 0.0196971	total: 2m 36s	remaining: 42s
# 788:	learn: 0.0196966	total: 2m 36s	remaining: 41.8s
# 789:	learn: 0.0196958	total: 2m 36s	remaining: 41.6s
# 790:	learn: 0.0196951	total: 2m 36s	remaining: 41.4s
# 791:	learn: 0.0196945	total: 2m 36s	remaining: 41.2s
# 792:	learn: 0.0196940	total: 2m 36s	remaining: 41s
# 793:	learn: 0.0196932	total: 2m 37s	remaining: 40.8s
# 794:	learn: 0.0196925	total: 2m 37s	remaining: 40.6s
# 795:	learn: 0.0196918	total: 2m 37s	remaining: 40.4s
# 796:	learn: 0.0196910	total: 2m 37s	remaining: 40.2s
# 797:	learn: 0.0196904	total: 2m 37s	remaining: 40s
# 798:	learn: 0.0196898	total: 2m 38s	remaining: 39.8s
# 799:	learn: 0.0196893	total: 2m 38s	remaining: 39.5s
# 800:	learn: 0.0196886	total: 2m 38s	remaining: 39.3s
# 801:	learn: 0.0196880	total: 2m 38s	remaining: 39.1s
# 802:	learn: 0.0196874	total: 2m 38s	remaining: 38.9s
# 803:	learn: 0.0196866	total: 2m 38s	remaining: 38.7s
# 804:	learn: 0.0196861	total: 2m 39s	remaining: 38.5s
# 805:	learn: 0.0196856	total: 2m 39s	remaining: 38.3s
# 806:	learn: 0.0196849	total: 2m 39s	remaining: 38.1s
# 807:	learn: 0.0196843	total: 2m 39s	remaining: 37.9s
# 808:	learn: 0.0196837	total: 2m 39s	remaining: 37.7s
# 809:	learn: 0.0196832	total: 2m 39s	remaining: 37.5s
# 810:	learn: 0.0196826	total: 2m 40s	remaining: 37.3s
# 811:	learn: 0.0196822	total: 2m 40s	remaining: 37.1s
# 812:	learn: 0.0196816	total: 2m 40s	remaining: 36.9s
# 813:	learn: 0.0196810	total: 2m 40s	remaining: 36.7s
# 814:	learn: 0.0196805	total: 2m 40s	remaining: 36.5s
# 815:	learn: 0.0196799	total: 2m 40s	remaining: 36.3s
# 816:	learn: 0.0196794	total: 2m 40s	remaining: 36.1s
# 817:	learn: 0.0196789	total: 2m 41s	remaining: 35.8s
# 818:	learn: 0.0196782	total: 2m 41s	remaining: 35.6s
# 819:	learn: 0.0196776	total: 2m 41s	remaining: 35.4s
# 820:	learn: 0.0196771	total: 2m 41s	remaining: 35.2s
# 821:	learn: 0.0196764	total: 2m 41s	remaining: 35s
# 822:	learn: 0.0196757	total: 2m 41s	remaining: 34.8s
# 823:	learn: 0.0196753	total: 2m 42s	remaining: 34.6s
# 824:	learn: 0.0196745	total: 2m 42s	remaining: 34.4s
# 825:	learn: 0.0196739	total: 2m 42s	remaining: 34.2s
# 826:	learn: 0.0196732	total: 2m 42s	remaining: 34s
# 827:	learn: 0.0196726	total: 2m 42s	remaining: 33.8s
# 828:	learn: 0.0196720	total: 2m 43s	remaining: 33.6s
# 829:	learn: 0.0196715	total: 2m 43s	remaining: 33.4s
# 830:	learn: 0.0196710	total: 2m 43s	remaining: 33.2s
# 831:	learn: 0.0196704	total: 2m 43s	remaining: 33s
# 832:	learn: 0.0196696	total: 2m 43s	remaining: 32.8s
# 833:	learn: 0.0196688	total: 2m 44s	remaining: 32.6s
# 834:	learn: 0.0196683	total: 2m 44s	remaining: 32.4s
# 835:	learn: 0.0196677	total: 2m 44s	remaining: 32.2s
# 836:	learn: 0.0196672	total: 2m 44s	remaining: 32s
# 837:	learn: 0.0196667	total: 2m 44s	remaining: 31.8s
# 838:	learn: 0.0196662	total: 2m 44s	remaining: 31.6s
# 839:	learn: 0.0196656	total: 2m 45s	remaining: 31.4s
# 840:	learn: 0.0196651	total: 2m 45s	remaining: 31.2s
# 841:	learn: 0.0196645	total: 2m 45s	remaining: 31s
# 842:	learn: 0.0196637	total: 2m 45s	remaining: 30.8s
# 843:	learn: 0.0196632	total: 2m 45s	remaining: 30.6s
# 844:	learn: 0.0196626	total: 2m 45s	remaining: 30.4s
# 845:	learn: 0.0196620	total: 2m 46s	remaining: 30.2s
# 846:	learn: 0.0196614	total: 2m 46s	remaining: 30s
# 847:	learn: 0.0196608	total: 2m 46s	remaining: 29.8s
# 848:	learn: 0.0196602	total: 2m 46s	remaining: 29.6s
# 849:	learn: 0.0196596	total: 2m 46s	remaining: 29.4s
# 850:	learn: 0.0196591	total: 2m 46s	remaining: 29.2s
# 851:	learn: 0.0196585	total: 2m 47s	remaining: 29s
# 852:	learn: 0.0196578	total: 2m 47s	remaining: 28.8s
# 853:	learn: 0.0196573	total: 2m 47s	remaining: 28.6s
# 854:	learn: 0.0196568	total: 2m 47s	remaining: 28.4s
# 855:	learn: 0.0196563	total: 2m 47s	remaining: 28.2s
# 856:	learn: 0.0196557	total: 2m 48s	remaining: 28s
# 857:	learn: 0.0196551	total: 2m 48s	remaining: 27.8s
# 858:	learn: 0.0196545	total: 2m 48s	remaining: 27.6s
# 859:	learn: 0.0196540	total: 2m 48s	remaining: 27.5s
# 860:	learn: 0.0196530	total: 2m 48s	remaining: 27.2s
# 861:	learn: 0.0196526	total: 2m 48s	remaining: 27s
# 862:	learn: 0.0196520	total: 2m 49s	remaining: 26.9s
# 863:	learn: 0.0196515	total: 2m 49s	remaining: 26.7s
# 864:	learn: 0.0196510	total: 2m 49s	remaining: 26.4s
# 865:	learn: 0.0196504	total: 2m 49s	remaining: 26.2s
# 866:	learn: 0.0196499	total: 2m 49s	remaining: 26s
# 867:	learn: 0.0196493	total: 2m 50s	remaining: 25.9s
# 868:	learn: 0.0196488	total: 2m 50s	remaining: 25.6s
# 869:	learn: 0.0196483	total: 2m 50s	remaining: 25.4s
# 870:	learn: 0.0196478	total: 2m 50s	remaining: 25.2s
# 871:	learn: 0.0196473	total: 2m 50s	remaining: 25s
# 872:	learn: 0.0196467	total: 2m 50s	remaining: 24.8s
# 873:	learn: 0.0196463	total: 2m 50s	remaining: 24.6s
# 874:	learn: 0.0196458	total: 2m 51s	remaining: 24.4s
# 875:	learn: 0.0196453	total: 2m 51s	remaining: 24.2s
# 876:	learn: 0.0196447	total: 2m 51s	remaining: 24s
# 877:	learn: 0.0196441	total: 2m 51s	remaining: 23.9s
# 878:	learn: 0.0196435	total: 2m 51s	remaining: 23.6s
# 879:	learn: 0.0196431	total: 2m 51s	remaining: 23.5s
# 880:	learn: 0.0196427	total: 2m 52s	remaining: 23.3s
# 881:	learn: 0.0196422	total: 2m 52s	remaining: 23.1s
# 882:	learn: 0.0196417	total: 2m 52s	remaining: 22.9s
# 883:	learn: 0.0196410	total: 2m 52s	remaining: 22.7s
# 884:	learn: 0.0196405	total: 2m 53s	remaining: 22.5s
# 885:	learn: 0.0196401	total: 2m 53s	remaining: 22.3s
# 886:	learn: 0.0196396	total: 2m 53s	remaining: 22.1s
# 887:	learn: 0.0196391	total: 2m 53s	remaining: 21.9s
# 888:	learn: 0.0196386	total: 2m 53s	remaining: 21.7s
# 889:	learn: 0.0196380	total: 2m 53s	remaining: 21.5s
# 890:	learn: 0.0196374	total: 2m 54s	remaining: 21.3s
# 891:	learn: 0.0196367	total: 2m 54s	remaining: 21.1s
# 892:	learn: 0.0196360	total: 2m 54s	remaining: 20.9s
# 893:	learn: 0.0196357	total: 2m 54s	remaining: 20.7s
# 894:	learn: 0.0196351	total: 2m 54s	remaining: 20.5s
# 895:	learn: 0.0196347	total: 2m 54s	remaining: 20.3s
# 896:	learn: 0.0196341	total: 2m 55s	remaining: 20.1s
# 897:	learn: 0.0196337	total: 2m 55s	remaining: 19.9s
# 898:	learn: 0.0196330	total: 2m 55s	remaining: 19.7s
# 899:	learn: 0.0196326	total: 2m 55s	remaining: 19.5s
# 900:	learn: 0.0196321	total: 2m 55s	remaining: 19.3s
# 901:	learn: 0.0196314	total: 2m 55s	remaining: 19.1s
# 902:	learn: 0.0196311	total: 2m 56s	remaining: 18.9s
# 903:	learn: 0.0196304	total: 2m 56s	remaining: 18.7s
# 904:	learn: 0.0196300	total: 2m 56s	remaining: 18.5s
# 905:	learn: 0.0196295	total: 2m 56s	remaining: 18.3s
# 906:	learn: 0.0196290	total: 2m 56s	remaining: 18.1s
# 907:	learn: 0.0196285	total: 2m 56s	remaining: 17.9s
# 908:	learn: 0.0196280	total: 2m 57s	remaining: 17.7s
# 909:	learn: 0.0196274	total: 2m 57s	remaining: 17.5s
# 910:	learn: 0.0196271	total: 2m 57s	remaining: 17.3s
# 911:	learn: 0.0196267	total: 2m 57s	remaining: 17.1s
# 912:	learn: 0.0196263	total: 2m 57s	remaining: 16.9s
# 913:	learn: 0.0196258	total: 2m 57s	remaining: 16.7s
# 914:	learn: 0.0196253	total: 2m 58s	remaining: 16.5s
# 915:	learn: 0.0196250	total: 2m 58s	remaining: 16.3s
# 916:	learn: 0.0196245	total: 2m 58s	remaining: 16.1s
# 917:	learn: 0.0196241	total: 2m 58s	remaining: 15.9s
# 918:	learn: 0.0196237	total: 2m 58s	remaining: 15.7s
# 919:	learn: 0.0196233	total: 2m 58s	remaining: 15.6s
# 920:	learn: 0.0196228	total: 2m 59s	remaining: 15.4s
# 921:	learn: 0.0196222	total: 2m 59s	remaining: 15.2s
# 922:	learn: 0.0196218	total: 2m 59s	remaining: 15s
# 923:	learn: 0.0196213	total: 2m 59s	remaining: 14.8s
# 924:	learn: 0.0196210	total: 2m 59s	remaining: 14.6s
# 925:	learn: 0.0196203	total: 2m 59s	remaining: 14.4s
# 926:	learn: 0.0196198	total: 3m	remaining: 14.2s
# 927:	learn: 0.0196194	total: 3m	remaining: 14s
# 928:	learn: 0.0196188	total: 3m	remaining: 13.8s
# 929:	learn: 0.0196183	total: 3m	remaining: 13.6s
# 930:	learn: 0.0196179	total: 3m	remaining: 13.4s
# 931:	learn: 0.0196174	total: 3m	remaining: 13.2s
# 932:	learn: 0.0196170	total: 3m 1s	remaining: 13s
# 933:	learn: 0.0196166	total: 3m 1s	remaining: 12.8s
# 934:	learn: 0.0196161	total: 3m 1s	remaining: 12.6s
# 935:	learn: 0.0196155	total: 3m 1s	remaining: 12.4s
# 936:	learn: 0.0196150	total: 3m 1s	remaining: 12.2s
# 937:	learn: 0.0196146	total: 3m 2s	remaining: 12s
# 938:	learn: 0.0196143	total: 3m 2s	remaining: 11.8s
# 939:	learn: 0.0196138	total: 3m 2s	remaining: 11.6s
# 940:	learn: 0.0196133	total: 3m 2s	remaining: 11.4s
# 941:	learn: 0.0196129	total: 3m 2s	remaining: 11.3s
# 942:	learn: 0.0196122	total: 3m 2s	remaining: 11.1s
# 943:	learn: 0.0196118	total: 3m 3s	remaining: 10.9s
# 944:	learn: 0.0196113	total: 3m 3s	remaining: 10.7s
# 945:	learn: 0.0196107	total: 3m 3s	remaining: 10.5s
# 946:	learn: 0.0196101	total: 3m 3s	remaining: 10.3s
# 947:	learn: 0.0196097	total: 3m 3s	remaining: 10.1s
# 948:	learn: 0.0196092	total: 3m 3s	remaining: 9.88s
# 949:	learn: 0.0196086	total: 3m 4s	remaining: 9.69s
# 950:	learn: 0.0196083	total: 3m 4s	remaining: 9.5s
# 951:	learn: 0.0196079	total: 3m 4s	remaining: 9.3s
# 952:	learn: 0.0196075	total: 3m 4s	remaining: 9.11s
# 953:	learn: 0.0196071	total: 3m 4s	remaining: 8.91s
# 954:	learn: 0.0196063	total: 3m 4s	remaining: 8.71s
# 955:	learn: 0.0196058	total: 3m 5s	remaining: 8.52s
# 956:	learn: 0.0196054	total: 3m 5s	remaining: 8.32s
# 957:	learn: 0.0196049	total: 3m 5s	remaining: 8.13s
# 958:	learn: 0.0196044	total: 3m 5s	remaining: 7.94s
# 959:	learn: 0.0196037	total: 3m 5s	remaining: 7.74s
# 960:	learn: 0.0196032	total: 3m 6s	remaining: 7.55s
# 961:	learn: 0.0196028	total: 3m 6s	remaining: 7.36s
# 962:	learn: 0.0196022	total: 3m 6s	remaining: 7.16s
# 963:	learn: 0.0196018	total: 3m 6s	remaining: 6.97s
# 964:	learn: 0.0196014	total: 3m 6s	remaining: 6.77s
# 965:	learn: 0.0196010	total: 3m 6s	remaining: 6.58s
# 966:	learn: 0.0196004	total: 3m 7s	remaining: 6.39s
# 967:	learn: 0.0196001	total: 3m 7s	remaining: 6.19s
# 968:	learn: 0.0195996	total: 3m 7s	remaining: 6s
# 969:	learn: 0.0195991	total: 3m 7s	remaining: 5.8s
# 970:	learn: 0.0195987	total: 3m 7s	remaining: 5.61s
# 971:	learn: 0.0195983	total: 3m 7s	remaining: 5.41s
# 972:	learn: 0.0195976	total: 3m 8s	remaining: 5.22s
# 973:	learn: 0.0195970	total: 3m 8s	remaining: 5.02s
# 974:	learn: 0.0195966	total: 3m 8s	remaining: 4.83s
# 975:	learn: 0.0195962	total: 3m 8s	remaining: 4.64s
# 976:	learn: 0.0195957	total: 3m 8s	remaining: 4.44s
# 977:	learn: 0.0195951	total: 3m 8s	remaining: 4.25s
# 978:	learn: 0.0195947	total: 3m 9s	remaining: 4.06s
# 979:	learn: 0.0195943	total: 3m 9s	remaining: 3.86s
# 980:	learn: 0.0195939	total: 3m 9s	remaining: 3.67s
# 981:	learn: 0.0195936	total: 3m 9s	remaining: 3.48s
# 982:	learn: 0.0195932	total: 3m 9s	remaining: 3.28s
# 983:	learn: 0.0195927	total: 3m 9s	remaining: 3.09s
# 984:	learn: 0.0195923	total: 3m 10s	remaining: 2.9s
# 985:	learn: 0.0195919	total: 3m 10s	remaining: 2.7s
# 986:	learn: 0.0195915	total: 3m 10s	remaining: 2.51s
# 987:	learn: 0.0195912	total: 3m 10s	remaining: 2.32s
# 988:	learn: 0.0195906	total: 3m 10s	remaining: 2.12s
# 989:	learn: 0.0195902	total: 3m 11s	remaining: 1.93s
# 990:	learn: 0.0195898	total: 3m 11s	remaining: 1.74s
# 991:	learn: 0.0195895	total: 3m 11s	remaining: 1.54s
# 992:	learn: 0.0195891	total: 3m 11s	remaining: 1.35s
# 993:	learn: 0.0195887	total: 3m 11s	remaining: 1.16s
# 994:	learn: 0.0195883	total: 3m 11s	remaining: 965ms
# 995:	learn: 0.0195879	total: 3m 12s	remaining: 771ms
# 996:	learn: 0.0195874	total: 3m 12s	remaining: 579ms
# 997:	learn: 0.0195869	total: 3m 12s	remaining: 386ms
# 998:	learn: 0.0195865	total: 3m 12s	remaining: 193ms
# 999:	learn: 0.0195861	total: 3m 12s	remaining: 0us
# Finished training model catboost
